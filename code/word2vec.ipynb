# %%
import pandas as pd
df = pd.read_excel('text_analysis_ad_sample.xlsx', index_col=0)
df
# Out:
#      index                                              商品名称    商品类别   出版年  \
# 0     1596                                五华牌香烟[May Blossom]    烟草制品  1932
# 1     5627  韦廉士红色清导丸[Dr.Willams' Pink Pills For Pale People]      药品  1918
# 2    13532                   大炮台香烟[Three Castles Cigarettes]    烟草制品  1935
# 3     1133                                婴孩自己药片[Baby's Own]      药品  1930
# 4     3146                                     亚士北罗药片[Aspro]      药品  1933
# ..     ...                                               ...     ...   ...
# 495  14176                                             安住蚊烟香  化肥及杀虫剂  1935
# 496  11610                                  第威德润肠丸[DeWitt's]      药品  1934
# 497  10256                                       如意膏[She-Ko]      药品  1934
# 498   9176                                             六零六药膏      药品  1923
# 499   6411                三炮台烟[The Three Caftles Cigarettes]    烟草制品  1919
#
#                                                   广告文本  \
# 0    兰勃脱白脱勒公司 五华牌香烟 佛及尼埃香烟  二十枝装每包售国币大洋二角 五十枝装每罐售国币...
# 1    讲求卫生为人生本性天理固然也 人生首贵逐日大便通畅有序为天然所当如此也如若大便不利大肠阻塞则...
# 2                                    香味馥郁,不让名花 另有三炮台出售
# 3    差肩儿女 秀慧康强 闽有佳音讃羡婴孩自己药片 每年此际小儿患肠胃病者甚多而尤以南方各地天气翳...
# 4    何以亚士北罗是妇女们的腻友？各国妇女力证亚士北罗药片是她们最需要的药物！为什么？她们的经验知...
# ..                                                 ...
# 495  安住蚊烟香 臭虫立毙药粉 世界第一名产 安住蚊烟香 蚊见逃慌慌 暑夜不用帐 包睡到天光 汉口...
# 496  眉色清秀 气色壮旺 此第威德润肠丸之功也 第威德润肠丸系以草药炼制纯粹和平十分安全功能清理肠...
# 497  汤火烫伤 立攃如意膏可免严重之后果 皮肤受伤当以灼烫最痛苦其又因此震激而致命者治疗灼烫止痛消...
# 498  清血解毒六零六 花柳梅毒瘰*疮疖癣疥**及筋骨酸痛四肢麻木半身疯*等症状虽异其发生之原理莫不...
# 499   三炮台香烟,'到底是好 三炮台 好香烟 敬宾客 美观瞻 市中日日新牌见 到底不如老牌烟 名不虚传
#
#                                 广告标题
# 0      五华牌香烟,"兰勃脱白脱勒公司 五华牌香烟 佛及尼埃香烟"
# 1          韦廉士红色清导丸:'讲求卫生为人生本性天理固然也'
# 2                  大炮台香烟,"香味馥郁 不让名花"
# 3    婴孩自己药片,"差肩儿女 秀慧康强 闽有佳音赞美婴孩自己药片"
# 4                     亚士北罗药片,"妇女之腻友"
# ..                               ...
# 495                   安住蚊烟香,"世界第一名产"
# 496               第威德润肠丸,"眉色清秀 气色壮旺"
# 497          如意膏,"汤火烫伤 立攃如意膏可免严重之后果"
# 498                    六零六,"清血解毒六零六"
# 499            三炮台香烟,"到底是好 三炮台 名不虚传"
#
# [500 rows x 6 columns]

# %%
import jieba
# Define a function to perform Chinese word segmentation on input text
def clean_text(text):
    # Use jieba.lcut to segment the input text into words, returning a list of words
    words=jieba.lcut(text)
    # Join the segmented words with a space and return the resulting string
    return ' '.join(words)

# Apply the clean_text function to each element in the '广告文本' column of the DataFrame
# and store the segmented results in a new column named '广告文本分词'
df['广告文本分词']=df['广告文本'].apply(clean_text)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/gt/hr3zd3gd7n9dmb8x_bjswg_00000gn/T/jieba.cache
# Loading model cost 0.423 seconds.
# Prefix dict has been built successfully.

# %%
df['广告文本分词']
# Out:
# 0      兰勃 脱白 脱勒 公司   五华 牌 香烟   佛及 尼埃 香烟     二十 枝装 每包 ...
# 1      讲求 卫生 为 人生 本性 天理 固然 也   人生 首贵 逐日 大便 通畅 有序 为 天然...
# 2                            香味 馥郁 , 不让 名花   另 有 三 炮台 出售
# 3      差肩 儿女   秀慧 康强   闽有 佳音 讃 羡 婴孩 自己 药片   每年 此际 小儿 ...
# 4      何以 亚士 北罗 是 妇女 们 的 腻友 ？ 各国 妇女 力证 亚士 北罗 药片 是 她们 ...
#                              ...
# 495    安住 蚊烟香   臭虫 立毙 药粉   世界 第一名 产   安住 蚊烟香   蚊见 逃 慌...
# 496    眉色 清秀   气色 壮旺   此 第 威德 润肠 丸 之功 也   第 威德 润肠 丸系 ...
# 497    汤火 烫伤   立 攃 如意 膏 可免 严重 之 后果   皮肤 受伤 当以 灼烫 最 痛苦...
# 498    清血 解毒 六零 六   花柳 梅毒 瘰 * 疮 疖 癣疥 * * 及 筋骨 酸痛 四肢 麻...
# 499    三 炮台 香烟 , ' 到底 是 好   三 炮台   好 香烟   敬 宾客   美 观瞻...
# Name: 广告文本分词, Length: 500, dtype: object

# %%
from gensim.test.utils import common_texts
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
sentences=df['广告文本分词'].apply(lambda x: x.split()).tolist()
sentences
# Out:
# [['兰勃',
#   '脱白',
#   '脱勒',
#   '公司',
#   '五华',
#   '牌',
#   '香烟',
#   '佛及',
#   '尼埃',
#   '香烟',
#   '二十',
#   '枝装',
#   '每包',
#   '售',
#   '国币',
#   '大洋',
#   '二角',
#   '五十',
#   '枝装',
#   '每罐',
#   '售',
#   '国币',
#   '大洋',
#   '五角'],
#  ['讲求',
#   '卫生',
#   '为',
#   '人生',
#   '本性',
#   '天理',
#   '固然',
#   '也',
#   '人生',
#   '首贵',
#   '逐日',
#   '大便',
#   '通畅',
#   '有序',
#   '为',
#   '天然',
#   '所当',
#   '如此',
#   '也',
#   '如若',
#   '大便',
#   '不利',
#   '大',
#   '肠阻塞',
#   '则',
#   '胃失',
#   '消化',
#   '疾病',
#   '头痛',
#   '肝火',
#   '上升',
#   '胆汁',
#   '不',
#   '调',
#   '口气',
#   '积浊',
#   '舌现',
#   '黄苔',
#   '诸恙',
#   '接踵',
#   '而',
#   '起',
#   '矣',
#   '凡',
#   '此皆须',
#   '服用',
#   '韦廉士',
#   '大',
#   '医生',
#   '红色',
#   '清导丸',
#   '以利',
#   '大便',
#   '俾得',
#   '体质',
#   '强健',
#   '百病',
#   '不侵',
#   '也况',
#   '此丸',
#   '之',
#   '功力',
#   '天然',
#   '平和',
#   '不尚',
#   '霸烈',
#   '广东省',
#   '城',
#   '医生',
#   '学',
#   '研究会',
#   '*',
#   '生',
#   '先生',
#   '来示',
#   '云弟',
#   '患大',
#   '便秘',
#   '结之症',
#   '一月',
#   '有余',
#   '困苦',
#   '万状',
#   '难以',
#   '言喻',
#   '服用',
#   '韦廉士',
#   '红色',
#   '清导丸',
#   '数粒',
#   '大便',
#   '畅达',
#   '于是',
#   '常为',
#   '服用',
#   '身体',
#   '爽健为',
#   '半生',
#   '以来',
#   '所',
#   '未有',
#   '也',
#   '如',
#   '尊处',
#   '无从',
#   '购买',
#   '韦廉士',
#   '红色',
#   '清导丸',
#   '祈即',
#   '邮票',
#   '大洋',
#   '六角',
#   '至',
#   '上海',
#   '四川',
#   '路',
#   '九十六',
#   '号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '原班',
#   '邮奉',
#   '一瓶',
#   '可',
#   '也'],
#  ['香味', '馥郁', ',', '不让', '名花', '另', '有', '三', '炮台', '出售'],
#  ['差肩',
#   '儿女',
#   '秀慧',
#   '康强',
#   '闽有',
#   '佳音',
#   '讃',
#   '羡',
#   '婴孩',
#   '自己',
#   '药片',
#   '每年',
#   '此际',
#   '小儿',
#   '患',
#   '肠胃病',
#   '者',
#   '甚',
#   '多',
#   '而',
#   '尤以',
#   '南方',
#   '各地',
#   '天气',
#   '翳',
#   '热',
#   '*',
#   '颣',
#   '充斥',
#   '之区',
#   '为',
#   '最',
#   '然而',
#   '刘君',
#   '强',
#   '逹',
#   '（',
#   '福州',
#   '南台',
#   '梅亭',
#   '山馆',
#   '）',
#   '家有',
#   '差肩',
#   '儿女',
#   '而',
#   '均',
#   '秀慧康',
#   '强者',
#   '果何法',
#   '以致',
#   '之乎',
#   '刘君云',
#   '鄙人',
#   '对于',
#   '贵局',
#   '所出',
#   '之',
#   '婴孩',
#   '自己',
#   '药片',
#   '甚佩其',
#   '功效',
#   '之',
#   '霊',
#   '验',
#   '药性',
#   '之',
#   '和平',
#   '舍下',
#   '儿女',
#   '常',
#   '因',
#   '食物',
#   '不节',
#   '发生',
#   '消化不良',
#   '肌热',
#   '烦燥',
#   '肚疼',
#   '泻泻',
#   '等',
#   '症',
#   '从前',
#   '未知',
#   '婴孩',
#   '药片',
#   '之功',
#   '时感',
#   '求医',
#   '之苦',
#   '今则',
#   '凡遇',
#   '上述',
#   '诸症',
#   '投',
#   '以此',
#   '片均',
#   '得速',
#   '愈',
#   '是',
#   '真',
#   '有',
#   '儿女',
#   '之',
#   '家庭',
#   '不可',
#   '不备',
#   '之',
#   '圣药',
#   '也',
#   '婴孩',
#   '自己',
#   '药片',
#   '系',
#   '韦廉士',
#   '之',
#   '儿科',
#   '専',
#   '药',
#   '统治',
#   '小儿',
#   '食积',
#   '腹痛',
#   '发热',
#   '便秘',
#   '呕吐',
#   '泄泻',
#   '伤风',
#   '痰厥',
#   '出牙',
#   '蛔虫',
#   '等',
#   '症',
#   '逺',
#   '东',
#   '总',
#   '发行',
#   '上海',
#   '江西',
#   '路',
#   '六十',
#   '号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '各埠',
#   '药房',
#   '均',
#   '有',
#   '代售'],
#  ['何以',
#   '亚士',
#   '北罗',
#   '是',
#   '妇女',
#   '们',
#   '的',
#   '腻友',
#   '？',
#   '各国',
#   '妇女',
#   '力证',
#   '亚士',
#   '北罗',
#   '药片',
#   '是',
#   '她们',
#   '最',
#   '需要',
#   '的',
#   '药物',
#   '！',
#   '为什么',
#   '？',
#   '她们',
#   '的',
#   '经验',
#   '知到',
#   '亚士',
#   '北罗',
#   '药片',
#   '功能',
#   '最',
#   '宏大',
#   ',',
#   '安全',
#   ',',
#   '可靠',
#   ',',
#   '物质',
#   '纯净',
#   ',',
#   '不含',
#   '别种',
#   '危险性',
#   '药料',
#   ',',
#   '故',
#   '妇女',
#   '们',
#   '最',
#   '信用',
#   '的',
#   '只有',
#   '亚士',
#   '北罗',
#   '药片',
#   '！',
#   '亚士',
#   '北罗',
#   '药片',
#   '的',
#   '功用',
#   ':',
#   '五分钟',
#   '内立止',
#   '各种',
#   '痛症',
#   '伤风感冒',
#   '失眠',
#   '一服',
#   '即',
#   '愈',
#   '何以',
#   '妇女',
#   '们',
#   '对于',
#   '亚士',
#   '北罗',
#   '比',
#   '丈夫',
#   '和',
#   '爱人',
#   '更',
#   '爱慕',
#   '？',
#   '婚前',
#   '！',
#   '未婚',
#   '女子',
#   '对',
#   '爱人',
#   '的',
#   '爱情',
#   '亲热',
#   '得',
#   '很',
#   '利害',
#   '但是',
#   '不',
#   '识趣',
#   '的',
#   '毛病',
#   '侵害',
#   '她',
#   '更为',
#   '利害',
#   '在',
#   '他',
#   '月经',
#   '来',
#   '的',
#   '时期',
#   '最易',
#   '使',
#   '他',
#   '感觉',
#   '到',
#   '最',
#   '不',
#   '安适',
#   '的',
#   '是',
#   '头痛',
#   '和',
#   '肚痛',
#   '两种',
#   '毛病',
#   '虽是',
#   '他',
#   '最',
#   '亲爱',
#   '的',
#   '爱人',
#   '也',
#   '没法',
#   '使',
#   '他',
#   '安适',
#   '惟有',
#   '亚士',
#   '北罗',
#   '药片',
#   '可以',
#   '立止',
#   '他',
#   '的',
#   '头痛',
#   '和',
#   '肚痛',
#   '回复',
#   '他',
#   '的',
#   '安适',
#   '和',
#   '快乐',
#   '亚士',
#   '北罗',
#   '药片',
#   '才',
#   '是',
#   '他们',
#   '最',
#   '亲爱',
#   '的',
#   '腻友',
#   '比',
#   '爱人',
#   '更',
#   '爱慕',
#   '故此',
#   '妇女',
#   '们',
#   '对亚士',
#   '北罗',
#   '药片',
#   '万分',
#   '的',
#   '信任',
#   '和',
#   '欢迎',
#   '婚后',
#   '！',
#   '女子',
#   '结了婚',
#   '她',
#   '的',
#   '唯一',
#   '责任',
#   '就是',
#   '养育',
#   '儿女',
#   '照料',
#   '丈夫',
#   '想尽',
#   '两种',
#   '责任',
#   '她',
#   '的',
#   '唯一',
#   '信赖',
#   '就是',
#   '亚士',
#   '北罗',
#   '药片',
#   '遇着',
#   '丈夫',
#   '和',
#   '儿女',
#   '发生',
#   '疾病',
#   '的',
#   '时候',
#   '如',
#   '头痛',
#   '肚痛',
#   '感冒',
#   '伤风',
#   '风湿',
#   '发热',
#   '使',
#   '她',
#   '的',
#   '芳心',
#   '最感',
#   '不安',
#   '用',
#   '了',
#   '亚士',
#   '北罗',
#   '药片',
#   '丈夫',
#   '和',
#   '儿女',
#   '也',
#   '得到',
#   '平安',
#   '可以',
#   '使',
#   '她',
#   '安乐',
#   '无忧',
#   '因为',
#   '丈夫',
#   '出外',
#   '工作',
#   '最易',
#   '伤风感冒',
#   '工作',
#   '过劳',
#   '神经病',
#   '或',
#   '头痛',
#   '儿女',
#   '最易',
#   '伤风感冒',
#   '发热',
#   '牙痛',
#   '肚痛',
#   '亚士',
#   '北罗',
#   '药片',
#   '可立止',
#   '葛',
#   '总',
#   '病症',
#   '退热',
#   '愈风',
#   '疾故',
#   '婚后',
#   '妇女',
#   '们',
#   '视亚士',
#   '北罗',
#   '药片',
#   '比',
#   '丈夫',
#   '和',
#   '儿女',
#   '更',
#   '重要',
#   '备有',
#   '亚士',
#   '北罗',
#   '药片',
#   '便',
#   '可',
#   '使',
#   '全家',
#   '平安',
#   '一',
#   '五分钟',
#   '至',
#   '十分钟',
#   '立止',
#   '剧烈',
#   '头痛',
#   '二',
#   '能',
#   '使',
#   '失眠',
#   '者',
#   '得',
#   '安乐',
#   '睡眠',
#   '三',
#   '能',
#   '驱除',
#   '各种',
#   '痛症',
#   '五',
#   '能治',
#   '牙痛',
#   '驱除',
#   '牙患',
#   '六',
#   '提神',
#   '却病',
#   '助消化',
#   '七',
#   '立止',
#   '各种',
#   '痛症',
#   '无害',
#   '于',
#   '此',
#   '八',
#   '治',
#   '腹部',
#   '肠',
#   '刺痛',
#   '九',
#   '以热',
#   '柠檬汁',
#   '溶和亚士',
#   '北罗',
#   '药片',
#   '两三片',
#   '饮服',
#   '立可',
#   '驱除',
#   '伤风感冒',
#   '十',
#   '五分钟',
#   '至',
#   '十分钟',
#   '立即',
#   '退热',
#   '十一',
#   '无论',
#   '在',
#   '舟车',
#   '家庭',
#   '随时随地',
#   '可以',
#   '服用',
#   '十二',
#   '专治',
#   '妇女',
#   '忧虑',
#   '过步',
#   '十三',
#   '能',
#   '醒酒',
#   '提神',
#   '十四',
#   '善治',
#   '大肠',
#   '热及',
#   '退',
#   '各种',
#   '热症',
#   '十五',
#   '用亚士',
#   '北罗',
#   '药片',
#   '治喉',
#   '痛',
#   '是',
#   '最',
#   '安全',
#   '之',
#   '法',
#   '小盒',
#   '三毫',
#   '中盒',
#   '六毫',
#   '大盒',
#   '一元',
#   '半',
#   '广州',
#   '沙面',
#   '天祥',
#   '洋行',
#   '总经理',
#   '各大',
#   '药房',
#   '均',
#   '有',
#   '代售',
#   'ASPRO'],
#  ['君亦患',
#   '咳嗽',
#   '而',
#   '夜眠',
#   '不安',
#   '乎',
#   '若然',
#   '今晚',
#   '请试',
#   '含',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '一枚',
#   '看其',
#   '清除',
#   '喉痒',
#   '消痰',
#   '止咳',
#   '使君',
#   '又',
#   '能',
#   '安睡',
#   '之',
#   '功效',
#   '为',
#   '如何',
#   '迅速',
#   '而',
#   '爽快',
#   '的',
#   '江苏',
#   '瓜埠罗',
#   '金定',
#   '君近',
#   '尝以',
#   '其',
#   '经历',
#   '见告',
#   '其书云',
#   '敝',
#   '人',
#   '现年',
#   '四十三岁',
#   '尽夜',
#   '咳嗽',
#   '不能',
#   '成睡',
#   '吞服',
#   '某',
#   '通行',
#   '止咳',
#   '丸',
#   '未有',
#   '效果',
#   '后经',
#   '敝',
#   '镇',
#   '仁慈',
#   '医院',
#   '马',
#   '医师',
#   '介绍',
#   '购用',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '不久',
#   '即',
#   '咳止',
#   '眠',
#   '安',
#   '矣',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片系',
#   '韦廉士',
#   '医生',
#   '药局',
#   '最新',
#   '出品',
#   '置',
#   '在',
#   '口中',
#   '缓缓',
#   '融化',
#   '立即',
#   '挥发',
#   '芬芳',
#   '治疗',
#   '之',
#   '气体',
#   '周循',
#   '口腔',
#   '达',
#   '咽喉',
#   '下行',
#   '气管',
#   '而',
#   '至',
#   '肺',
#   '尖能',
#   '直接',
#   '治疗',
#   '咳嗽',
#   '伤风',
#   '气管',
#   '支炎',
#   '以及',
#   '其他',
#   '喉胸',
#   '各疾',
#   '各大',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '迳',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '每瓶',
#   '七角',
#   '五分',
#   '邮力',
#   '不取'],
#  ['与', '爱人', '并', '坐', '读名', '小说', '吸大', '炮台', '其味', '津津', '乐而', '忘倦'],
#  ['美容',
#   '药料',
#   '花颜水',
#   '皮肤',
#   '能',
#   '令人',
#   '外貌',
#   '最易',
#   '*',
#   '变',
#   '虽然',
#   '生成',
#   '美丽',
#   '娇容',
#   '若任',
#   '皮肤',
#   '自成',
#   '粗陋',
#   '非独',
#   '不得',
#   '维持',
#   '原有',
#   '之美',
#   '且',
#   '不能',
#   '发挥',
#   '天性',
#   '之美',
#   '皮肤',
#   '之',
#   '关系',
#   '于',
#   '美丽',
#   '有',
#   '如此',
#   '也',
#   '自古',
#   '世间',
#   '自',
#   '*',
#   '其',
#   '容貌',
#   '丑陋',
#   '者',
#   '实属',
#   '不稀',
#   '此',
#   '又',
#   '人生',
#   '最大',
#   '之',
#   '遗憾',
#   '兹',
#   '有',
#   '日本',
#   '皮肤科',
#   '专门',
#   '大医',
#   '小岛',
#   '先生',
#   '多年',
#   '研究',
#   '自出心裁',
#   '发明',
#   '一种',
#   '良药',
#   '精制',
#   '而成',
#   '美容',
#   '药水',
#   '名曰',
#   '花颜水仅',
#   '以',
#   '数滴',
#   '滴入',
#   '洗脸水',
#   '中',
#   '或融',
#   '溶',
#   '数倍',
#   '至',
#   '清水',
#   '该盆内',
#   '之水',
#   '即逢',
#   '药水',
#   '而',
#   '变色',
#   '如乳',
#   '其馨',
#   '馥郁',
#   '触鼻',
#   '虽',
#   '鲜花',
#   '如',
#   '玫瑰',
#   '与',
#   '兰花',
#   '亦',
#   '退一步',
#   '且合',
#   '卫生',
#   '善治',
#   '皮肤',
#   '所',
#   '发小疮',
#   '如',
#   '面疱',
#   '暗疮',
#   '雀斑',
#   '粉刺',
#   '酒刺',
#   '汗疹',
#   '顽',
#   '廯',
#   '烟气',
#   '红',
#   '点',
#   '油光',
#   '瘰疬',
#   '等',
#   '诸症',
#   '讨厌',
#   '之物',
#   '凡',
#   '老幼',
#   '男女皆可',
#   '使用',
#   '此花',
#   '颜水',
#   '均',
#   '得',
#   '转丑',
#   '成美',
#   '花颜水',
#   '之',
#   '特色',
#   '最能',
#   '完全',
#   '皮肤',
#   '乃',
#   '成色',
#   '使',
#   '姿容',
#   '倍',
#   '极',
#   '光耀',
#   '足称',
#   '最上',
#   '妙品',
#   '请试',
#   '一瓶',
#   '以证本',
#   '药房',
#   '之言',
#   '不谬',
#   '药价',
#   '大',
#   '瓶',
#   '大洋',
#   '一元',
#   '小瓶',
#   '大洋',
#   '五角',
#   '试用',
#   '瓶',
#   '大洋',
#   '三角',
#   '五分'],
#  ['世界',
#   '惊奇',
#   '的',
#   '搜毒',
#   '杀菌',
#   '大',
#   '发明',
#   '有万兆',
#   '杀菌',
#   '力',
#   '杀绝',
#   '血中',
#   '毒菌',
#   '打破',
#   '千古',
#   '不治',
#   '的',
#   '血毒',
#   '顽恶癣',
#   '扫灭',
#   '花柳',
#   '各种',
#   '毒症',
#   '顽毒',
#   '入骨',
#   '狮标',
#   '血',
#   '药片',
#   '乃',
#   '德国',
#   '名医',
#   '赖',
#   '回氏',
#   '发明',
#   '无论',
#   '血毒',
#   '顽癣',
#   '恶癣',
#   '见',
#   '有',
#   '红斑',
#   '面热耳红',
#   '皮肉',
#   '浮肿',
#   '虫行',
#   '蚁',
#   '咬',
#   '毛发',
#   '易脱',
#   '等',
#   '状',
#   '花柳',
#   '疳',
#   '各种',
#   '毒症',
#   '及',
#   '皮肤',
#   '均',
#   '扫灭',
#   '无',
#   '逍大瓶',
#   '七元',
#   '小瓶',
#   '三元',
#   '十八',
#   '甫',
#   '*',
#   '威',
#   '永汉北',
#   '老威',
#   '十三行',
#   '安乐',
#   '大新',
#   '公司',
#   '先施',
#   '公司',
#   '十七',
#   '甫',
#   '仁寿',
#   '一德路',
#   '永雄',
#   '医所',
#   '代售'],
#  ['小儿',
#   '疾病',
#   '多',
#   '由',
#   '哺',
#   '喂',
#   '无定',
#   '或',
#   '过饱',
#   '而',
#   '起盖',
#   '小儿',
#   '娇嫩',
#   '之',
#   '肠胃',
#   '如使',
#   '之',
#   '工作',
#   '失宜',
#   '必至',
#   '紊乱',
#   '失序',
#   '而',
#   '引起',
#   '甚多',
#   '之',
#   '疾病',
#   '世界各地',
#   '千万',
#   '父母',
#   '对于',
#   '治疗',
#   '小儿',
#   '肠胃',
#   '失序',
#   '而',
#   '使',
#   '其',
#   '疾病',
#   '速',
#   '痊均',
#   '知',
#   '婴孩',
#   '自己',
#   '药片',
#   '功力',
#   '无比',
#   '关于',
#   '此事',
#   '满洲',
#   '锦州',
#   '公署',
#   '民政厅',
#   '冯君',
#   '广民',
#   '曾',
#   '来',
#   '书云',
#   '小儿',
#   '行八',
#   '现年',
#   '一岁',
#   '因',
#   '喂乳',
#   '无定',
#   '致',
#   '肠胃',
#   '失序',
#   '体气',
#   '虚弱',
#   '体胖',
#   '减瘦',
#   '幸经',
#   '本埠',
#   '仁济',
#   '药房',
#   '介绍',
#   '投以',
#   '婴孩',
#   '自己',
#   '药片',
#   '大见',
#   '功效',
#   '目下',
#   '身体',
#   '肥胖',
#   '活泼可爱',
#   '是',
#   '皆',
#   '婴孩',
#   '自己',
#   '药片',
#   '之功',
#   '也',
#   '曷',
#   '胜',
#   '感谢',
#   '之',
#   '至',
#   '婴孩',
#   '自己',
#   '药片',
#   '清理',
#   '内腑',
#   '效大性',
#   '和',
#   '故善治',
#   '肠胃',
#   '失序',
#   '退热',
#   '止',
#   '呕疗',
#   '便秘',
#   '泄泻',
#   '除',
#   '伤风',
#   '痰厥',
#   '平肚',
#   '痛及',
#   '出牙',
#   '各症',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '迳',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购买',
#   '每瓶',
#   '大洋',
#   '七角',
#   '六瓶',
#   '三元',
#   '五角',
#   '邮力',
#   '不取'],
#  ['梅毒',
#   '淋症',
#   '诸病',
#   '虽',
#   '坊间',
#   '有',
#   '卖',
#   '药',
#   '而',
#   '其',
#   '效能',
#   '确实',
#   '者',
#   '以哈郎',
#   '清血',
#   '补身',
#   '丸',
#   '为',
#   '第一',
#   '无论',
#   '何人',
#   '苟染',
#   '此症',
#   '必须',
#   '速服',
#   '哈郎',
#   '清血',
#   '补身',
#   '丸',
#   '勿',
#   '为',
#   '他',
#   '药所惑',
#   '此药',
#   '専',
#   '治',
#   '杨梅',
#   '结毒',
#   '鱼口',
#   '便毒',
#   '丁疳',
#   '横五淋',
#   '白浊',
#   '尿道',
#   '糜烂',
#   '小便',
#   '不通',
#   '时激痛',
#   '全身',
#   '发疹',
#   '顽毒',
#   '入骨',
#   '关节',
#   '疼痛',
#   '眼花',
#   '朦胧',
#   '毛',
#   '髪',
#   '脱落',
#   '痔疮',
#   '并发',
#   '咽喉',
#   '疼痛',
#   '声音',
#   '枯嘎',
#   '鼻梁',
#   '崩坏',
#   '腐落',
#   '一切',
#   '难症',
#   '若能',
#   '服用',
#   '此哈郎',
#   '清血',
#   '补身',
#   '丸',
#   '则',
#   '将',
#   '其',
#   '病源',
#   '之',
#   '毒菌',
#   '全然',
#   '驱处',
#   '根绝',
#   '净尽',
#   '无有',
#   '再',
#   '之虞',
#   '实为',
#   '环球',
#   '无比',
#   '之',
#   '霊',
#   '药',
#   '也',
#   '近',
#   '有售',
#   '同名',
#   '之',
#   '假药',
#   '者',
#   '赐顾',
#   '认明',
#   '顺和',
#   '堂字',
#   '様',
#   '及',
#   '骨牌',
#   '商标',
#   '为',
#   '要',
#   '药价',
#   '大',
#   '瓶',
#   '二元',
#   '每',
#   '打',
#   '二十元',
#   '小瓶',
#   '一元',
#   '二角',
#   '每',
#   '打',
#   '十二元',
#   '发售',
#   '本铺',
#   '大阪',
#   '清水',
#   '谷西',
#   '之',
#   '顺和',
#   '堂大',
#   '药房',
#   '经理',
#   '所',
#   '天津',
#   '旭街',
#   '东亚',
#   '公司',
#   '北京',
#   '东单',
#   '东亚',
#   '公司',
#   '北京',
#   '前',
#   '门外',
#   '信昌',
#   '洋行'],
#  ['大',
#   '炮台',
#   '芬芳',
#   '的',
#   '香味',
#   '胜似',
#   '甜蜜',
#   '的',
#   '歌曲',
#   '多么',
#   '使人',
#   '陶醉',
#   '啊',
#   '!',
#   '黄金',
#   '般的',
#   '烟丝',
#   '芝兰',
#   '般的',
#   '香味',
#   '真是',
#   '十二分',
#   '的',
#   '可爱',
#   '大',
#   '炮台',
#   '始终',
#   '不会',
#   '使',
#   '诸君',
#   '失望'],
#  ['舣',
#   '舟',
#   '柳阴',
#   '下',
#   '清风徐来',
#   '水波不兴',
#   '相',
#   '舆燃',
#   '大',
#   '炮台',
#   '徐徐',
#   '吸之',
#   '芬芳',
#   '甘凉',
#   '心神',
#   '爽适',
#   '胸无',
#   '织尘',
#   '矣'],
#  ['无往', '而', '非大', '炮台', '吸者', '另', '有', '三', '炮台', '出售'],
#  ['发生',
#   '风疹',
#   '如何',
#   '疗治',
#   '治疗',
#   '风疹',
#   '从前',
#   '有以',
#   '香木',
#   '焼',
#   '烟熏',
#   '之',
#   '或',
#   '以',
#   '止痒',
#   '药',
#   '水洗',
#   '之此',
#   '穜',
#   '治法',
#   '在',
#   '无',
#   '有',
#   '更佳',
#   '之',
#   '法',
#   '可用',
#   '时',
#   '当然',
#   '亦',
#   '属',
#   '*',
#   '胜',
#   '现在',
#   '则',
#   '有',
#   '更佳',
#   '更',
#   '便',
#   '更',
#   '卫生',
#   '更',
#   '有效',
#   '之',
#   '治法',
#   '即',
#   '搽',
#   '用',
#   '如意',
#   '膏',
#   '是',
#   '也',
#   '此膏',
#   '为',
#   '著名',
#   '韦廉士',
#   '医生',
#   '药局',
#   '疗肤',
#   '専',
#   '品',
#   '清凉',
#   '舒适',
#   '立能',
#   '止痒',
#   '速愈',
#   '风疹',
#   '南洋',
#   '梹',
#   '城',
#   '山顶',
#   '茶室',
#   '林君',
#   '豪英',
#   '来书云',
#   '鄙人',
#   '常患',
#   '风疹',
#   '遍身',
#   '搔痒',
#   '后',
#   '搽',
#   '如意',
#   '膏',
#   '奏效',
#   '神速',
#   '止痒',
#   '消疹',
#   '永无',
#   '复发',
#   '用',
#   '特书此',
#   '介绍',
#   '为同',
#   '病者',
#   '告焉',
#   '如意',
#   '膏',
#   '各',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '每盒',
#   '七角',
#   '六盒',
#   '三元',
#   '五角',
#   '邮费',
#   '不取'],
#  ['用',
#   '滚水',
#   '和',
#   '匀',
#   '便',
#   '成',
#   '牛肉',
#   '汁',
#   '每夜',
#   '睡前用',
#   '滚水',
#   '或',
#   '鲜奶',
#   '冲',
#   '保卫',
#   '尔',
#   '一羹',
#   '饮后',
#   '身体',
#   '强健',
#   '精神',
#   '充足',
#   '乃补身',
#   '无上',
#   '佳品',
#   '也',
#   '有',
#   '健体',
#   '补血',
#   '提神',
#   '之',
#   '功效',
#   '游山玩水',
#   '远道',
#   '旅行',
#   '时宜',
#   '携带',
#   '保卫',
#   '尔',
#   '牛肉',
#   '汁',
#   '随时随地',
#   '可用',
#   '如',
#   '觉惫倦',
#   '时',
#   '饮之能',
#   '提神',
#   '健体',
#   '增加',
#   '游兴',
#   '不少',
#   '各',
#   '公司',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '香港',
#   '总经理',
#   '和',
#   '记',
#   '洋行'],
#  ['妍媸',
#   '本',
#   '天赋',
#   '而成',
#   '无',
#   '可以',
#   '更易',
#   '之',
#   '也',
#   '今且',
#   '有',
#   '可以',
#   '人力',
#   '施之',
#   '何者',
#   '也',
#   '然其',
#   '本来',
#   '且',
#   '有',
#   '美容',
#   '者',
#   '预为',
#   '保持',
#   '之',
#   '丑陋',
#   '者',
#   '也',
#   '时',
#   '为',
#   '修饰',
#   '之',
#   '若',
#   '问',
#   '保持',
#   '与',
#   '修饰',
#   '之善法',
#   '则',
#   '条理',
#   '开列',
#   '于',
#   '左方',
#   '●',
#   '花颜水',
#   '为',
#   '皮肤',
#   '科学',
#   '专门',
#   '大医',
#   '小岛',
#   '享',
#   '先生',
#   '经历',
#   '多年',
#   '苦心',
#   '研究',
#   '确从',
#   '皮肤',
#   '上',
#   '考究',
#   '得来',
#   '之圣剂',
#   '早已',
#   '驰名',
#   '本国',
#   '各地',
#   '今本',
#   '药房',
#   '持',
#   '遵',
#   '先生',
#   '之方',
#   '细求',
#   '材料',
#   '精工',
#   '配合',
#   '运来',
#   '各国',
#   '俾',
#   '大众',
#   '得',
#   '沾',
#   '其益',
#   '凡',
#   '欲',
#   '保容者',
#   '请勿',
#   '等闲视之',
#   '●',
#   '花颜水',
#   '最近',
#   '盛行于',
#   '欧美',
#   '两洲',
#   '凡',
#   '男女',
#   '自',
#   '为',
#   '维持',
#   '其',
#   '脸上',
#   '者',
#   '确有',
#   '不可',
#   '一刻',
#   '缺少',
#   '此',
#   '化妆',
#   '药水',
#   '故',
#   '一时',
#   '有',
#   '曰',
#   '欲求',
#   '自己',
#   '颜容',
#   '艳美者',
#   '须要',
#   '重看',
#   '花颜水',
#   '●',
#   '花颜水',
#   '于',
#   '洗脸',
#   '之时',
#   '可滴',
#   '少量',
#   '于',
#   '洗面器',
#   '中',
#   '或',
#   '融解',
#   '二三倍',
#   '之',
#   '清水',
#   '而常为',
#   '使用',
#   '即可',
#   '全治',
#   '皮肤病',
#   '如',
#   '面',
#   '*',
#   '顽癣',
#   '粉刺',
#   '酒刺',
#   '汗疹',
#   '烟气',
#   '红点',
#   '晦色',
#   '油光',
#   '瘰疬',
#   '等',
#   '均',
#   '得',
#   '转丑',
#   '成美',
#   '至于',
#   '女子',
#   '搽',
#   '敷',
#   '白粉',
#   '若先',
#   '使用',
#   '此',
#   '药水',
#   '非唯',
#   '融化',
#   '之妙且',
#   '能豫防',
#   '白粉',
#   '中',
#   '所',
#   '含铅',
#   '毒',
#   '也',
#   '●',
#   '芳香',
#   '馥郁',
#   '薰风',
#   '勃勃',
#   '能',
#   '令人',
#   '发生',
#   '一种',
#   '愉快',
#   '者',
#   '则',
#   '其人',
#   '必为',
#   '常用',
#   '花颜水',
#   '故曰',
#   '交际',
#   '场面',
#   '确',
#   '不可',
#   '缺此',
#   '花颜水',
#   '乃',
#   '兼备',
#   '卫生',
#   '与',
#   '经济',
#   '为',
#   '化妆',
#   '用',
#   '最良',
#   '之',
#   '妙品',
#   '且',
#   '此',
#   '之',
#   '白粉',
#   '花露水',
#   '肥皂',
#   '等',
#   '化妆',
#   '用',
#   '之',
#   '材料',
#   '之',
#   '价格',
#   '廉而功',
#   '乃',
#   '大',
#   '幸勿',
#   '疑之',
#   '●',
#   '花颜水',
#   '可滴',
#   '数点',
#   '温水',
#   '或',
#   '凉水',
#   '中',
#   '即',
#   '依',
#   '化学',
#   '的',
#   '作用',
#   '清水',
#   '如',
#   '牛奶',
#   '成白',
#   '香风',
#   '发生',
#   '胸间',
#   '觉快',
#   '致使',
#   '用',
#   '不断',
#   '乃',
#   '可',
#   '除去',
#   '丑貌',
#   '换来',
#   '美颜',
#   '如',
#   '鲜花',
#   '故其',
#   '名曰',
#   '花颜水论',
#   '其',
#   '功效',
#   '可谓',
#   '近世',
#   '最新',
#   '化妆',
#   '用',
#   '之',
#   '第一品',
#   '●',
#   '花颜水',
#   '最',
#   '有效',
#   '儿童',
#   '或',
#   '遭',
#   '蚊',
#   '臭虫',
#   '啮',
#   '或',
#   '患汗',
#   '疮',
#   '与',
#   '一切',
#   '皮肤',
#   '风痒',
#   '青年',
#   '男女',
#   '脸上',
#   '发生',
#   '小疮',
#   '或',
#   '雀斑',
#   '酒刺',
#   '红',
#   '白点',
#   '等',
#   '患',
#   '均',
#   '可以',
#   '花颜水',
#   '搽',
#   '敷',
#   '每天',
#   '三次',
#   '必可保',
#   '痊愈',
#   '也',
#   '花颜水',
#   '凡',
#   '各埠大',
#   '药房',
#   '及',
#   '洋',
#   '雑',
#   '货',
#   '庄',
#   '均',
#   '有',
#   '代售',
#   '近有',
#   '奸商',
#   '仿造',
#   '假货',
#   '请认',
#   '此书',
#   '商标',
#   '为幸',
#   '花颜水',
#   '售价',
#   '大',
#   '瓶',
#   '大洋',
#   '一元',
#   '每',
#   '打',
#   '大洋',
#   '拾元',
#   '中瓶',
#   '大洋',
#   '五角',
#   '每',
#   '打',
#   '大洋',
#   '五元',
#   '小瓶',
#   '大洋',
#   '三角',
#   '五分',
#   '发售',
#   '所',
#   '大阪',
#   '东区',
#   '清水',
#   '谷',
#   '顺和',
#   '大',
#   '药房',
#   '总经理',
#   '上海',
#   '四',
#   '马路',
#   '中东',
#   '大',
#   '药房',
#   '上海',
#   '河南',
#   '路',
#   '华美',
#   '大',
#   '药房',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*'],
#  ['司令',
#   '牌',
#   '香烟',
#   '佛及',
#   '尼',
#   '挨',
#   '烟叶',
#   '所造',
#   '烟枝',
#   '顶',
#   '大',
#   '烟枝',
#   '特别',
#   '改良',
#   '放大',
#   '一应',
#   '时需',
#   '不仅',
#   '烟枝',
#   '顶',
#   '大烟',
#   '料',
#   '亦',
#   '最',
#   '上品',
#   '伦敦',
#   '惠斯民烟',
#   '公司',
#   '没',
#   '听',
#   '五十',
#   '枝'],
#  ['小儿',
#   '患病',
#   '有碍于',
#   '身体',
#   '发育',
#   '者',
#   '大抵',
#   '皆',
#   '由',
#   '肠胃',
#   '失序',
#   '而',
#   '起',
#   '是',
#   '故',
#   '父母',
#   '欲',
#   '其',
#   '儿女',
#   '康壮',
#   '欢愉',
#   '必须',
#   '使',
#   '其',
#   '肠胃',
#   '健全',
#   '而后',
#   '可',
#   '婴孩',
#   '自己',
#   '药片',
#   '业已',
#   '名闻',
#   '世界',
#   '具此',
#   '功能',
#   '良',
#   '以此',
#   '片味',
#   '美性',
#   '和',
#   '功宏效',
#   '大能',
#   '和',
#   '肠胃',
#   '健',
#   '消化',
#   '俾',
#   '小儿',
#   '确得',
#   '其',
#   '食物',
#   '之',
#   '滋补',
#   '而',
#   '保康',
#   '安',
#   '天津',
#   '东兴',
#   '大',
#   '*',
#   '张记',
#   '广货',
#   '庄',
#   '经理',
#   '张',
#   '君子',
#   '泉来',
#   '书云',
#   '[',
#   '小儿',
#   '元祥现',
#   '甚',
#   '壮健',
#   '但',
#   '在',
#   '周岁',
#   '时尝患',
#   '肠胃',
#   '剧病',
#   '后',
#   '投以',
#   '婴孩',
#   '自己',
#   '药片',
#   '即见',
#   '胃强',
#   '便',
#   '顺',
#   '安睡',
#   '不啼',
#   '从此',
#   '如遇',
#   '伤风',
#   '发热',
#   '令服',
#   '此片',
#   '无不',
#   '称心',
#   '故予',
#   '甚感',
#   '其良效',
#   '也',
#   ']',
#   '婴孩',
#   '自己',
#   '药片',
#   '统治',
#   '小儿',
#   '便秘',
#   '食积',
#   '腹痛',
#   '泄泻',
#   '痰厥',
#   '蛔虫',
#   '伤风',
#   '发热',
#   '出牙',
#   '痛苦',
#   '以及',
#   '其他',
#   '普通',
#   '肠胃',
#   '疾病',
#   '身体',
#   '不适',
#   '等',
#   '患',
#   '各',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '每瓶',
#   '七角',
#   '六瓶',
#   '三元',
#   '五角',
#   '邮费',
#   '不取'],
#  ['请君',
#   '注意',
#   '红锡包',
#   '香烟',
#   '外支装',
#   '每',
#   '听',
#   '内',
#   '有',
#   '保护',
#   '香烟',
#   '之圆',
#   '纸片',
#   '一张',
#   '于',
#   '有限',
#   '期内',
#   '凡积',
#   '得',
#   '此',
#   '穜',
#   '圆',
#   '纸片',
#   '贰',
#   '拾',
#   '张',
#   '即可',
#   '换取',
#   '精美',
#   '赛银',
#   '香烟盒',
#   '壹',
#   '只',
#   '掉换',
#   '处',
#   '各处',
#   '永泰',
#   '和',
#   '烟草',
#   '股份',
#   '有限公司'],
#  ['肾强',
#   '体健',
#   '䖏',
#   '䖏',
#   '占先',
#   '肾部',
#   '健全',
#   '。',
#   '自无',
#   '腰痛',
#   '、',
#   '背痛',
#   '、',
#   '等',
#   '症',
#   '。',
#   '身体',
#   '亦',
#   '强',
#   '。',
#   '按',
#   '肾',
#   '之',
#   '为',
#   '用',
#   '。',
#   '乃',
#   '吸收',
#   '血液',
#   '内之尿',
#   '强酸',
#   '毒',
#   '由',
#   '尿道',
#   '排泄',
#   '之',
#   '。',
#   '若',
#   '肾部',
#   '亏弱',
#   '。',
#   '即失',
#   '其',
#   '效用',
#   '而',
#   '尖锐',
#   '如',
#   '碎玻璃',
#   '之尿',
#   '强酸',
#   '晶',
#   '。',
#   '积储',
#   '肌肉',
#   '骨节',
#   '内',
#   '。',
#   '引起',
#   '剧烈',
#   '之',
#   '痛楚',
#   '。',
#   '第',
#   '威德',
#   '补肾',
#   '丸',
#   '能',
#   '恢复',
#   '肾部',
#   '健康',
#   '。',
#   '肾病',
#   '既',
#   '为',
#   '腰酸',
#   '、',
#   '背痛',
#   '等',
#   '之',
#   '祸根',
#   '。',
#   '补肾',
#   '自',
#   '为',
#   '强身',
#   '延寿',
#   '之良法',
#   '。',
#   '明证',
#   '－',
#   '服第',
#   '威德',
#   '补肾',
#   '丸',
#   '后',
#   '。',
#   '二十四',
#   '小时',
#   '内',
#   '。',
#   '小便',
#   '即',
#   '变成',
#   '淡蓝色',
#   '。',
#   '此即',
#   '药力',
#   '直达',
#   '肾部',
#   '之',
#   '明证',
#   '。',
#   '盖',
#   '第',
#   '威德',
#   '补肾',
#   '丸',
#   '即',
#   '以此',
#   '(',
#   '火米',
#   ')',
#   '替',
#   '连',
#   '蓝及',
#   '七种',
#   '名贵',
#   '药料',
#   '所制',
#   '。'],
#  ['血蛇',
#   '恶癣',
#   '救星',
#   '狮标',
#   '那必',
#   '敌血',
#   '毒片',
#   '此药',
#   '行销',
#   '各埠',
#   '十余年',
#   '治愈',
#   '登报',
#   '恭颂者',
#   '指不胜屈',
#   '无论',
#   '血',
#   '毒血',
#   '蛇',
#   '恶癣',
#   '见',
#   '有',
#   '痕痒',
#   '红',
#   '癍',
#   '面热耳红',
#   '皮肉',
#   '浮肿',
#   '虫行',
#   '蚁',
#   '咬',
#   '毛',
#   '髪',
#   '易',
#   '脱',
#   '等',
#   '状',
#   '花柳',
#   '疳',
#   '疔',
#   '各',
#   '穜',
#   '毒症',
#   '及',
#   '皮肤',
#   '疮',
#   '癞',
#   '均',
#   '埽',
#   '灭',
#   '无道',
#   '大',
#   '瓶',
#   '七元',
#   '小瓶',
#   '*',
#   '元',
#   '十八',
#   '甫',
#   '普威',
#   '永汉北',
#   '老威',
#   '太平',
#   '南',
#   '*',
#   '済',
#   '大新',
#   '公司',
#   '先施',
#   '公司',
#   '十七',
#   '甫',
#   '仁寿',
#   '代售',
#   '一德路',
#   '*',
#   '永雄',
#   '*',
#   '所',
#   '发行'],
#  ['壮强',
#   '胃肠',
#   '是',
#   '预防',
#   '瘴疫',
#   '之',
#   '第一',
#   '策',
#   '病由口',
#   '起',
#   '是',
#   '故',
#   '常为',
#   '绝对',
#   '壮强',
#   '之',
#   '胃肠',
#   '者',
#   '请',
#   '宜服',
#   '健胃',
#   '力',
#   '杀菌',
#   '力',
#   '强大',
#   '之',
#   '仁丹',
#   '以',
#   '保持',
#   '全家',
#   '之',
#   '康健'],
#  ['他',
#   '说',
#   '：',
#   '吸红锡包',
#   '最',
#   '合算',
#   '.',
#   '一则',
#   '香味',
#   '美妙',
#   '二则',
#   '价钱',
#   '公道',
#   '.',
#   '她',
#   '说',
#   '...',
#   '不错',
#   '所以',
#   '我',
#   '也',
#   '最',
#   '爱吸',
#   '红锡包',
#   '永泰',
#   '和',
#   '烟草',
#   '有限公司',
#   '总经理'],
#  ['肾亏',
#   '百病',
#   '生',
#   '肾为',
#   '滤清',
#   '血中',
#   '尿毒',
#   '之器',
#   '肾',
#   '如',
#   '亏弱',
#   '则',
#   '尿酸',
#   '之',
#   '毒质',
#   '随',
#   '血液',
#   '之',
#   '循环',
#   '侵害',
#   '身体',
#   '各部',
#   '以致',
#   '病痛',
#   '发生',
#   '上列',
#   '各症',
#   '即',
#   '因',
#   '肾亏',
#   '而',
#   '起',
#   '其',
#   '最',
#   '显者',
#   '为',
#   '背痛',
#   '腰酸',
#   '若',
#   '不速治',
#   '酿成',
#   '重症',
#   '为',
#   '患',
#   '甚',
#   '矣',
#   '兜安氏',
#   '秘制',
#   '保肾',
#   '丸',
#   '为',
#   '专治',
#   '肾亏',
#   '之',
#   '良药',
#   '功能化',
#   '尿酸',
#   '利小便',
#   '清',
#   '血液',
#   '补肾',
#   '力',
#   '肾强',
#   '血清',
#   '身自健',
#   '矣',
#   '凡',
#   '患',
#   '肾亏',
#   '者',
#   '宜速',
#   '服此',
#   '信誉',
#   '久',
#   '著之保',
#   '肾丸',
#   '也',
#   '上海',
#   '江西',
#   '路',
#   '四',
#   '八九',
#   '兜安氏',
#   '西药',
#   '公司',
#   '启',
#   '各埠',
#   '药房',
#   '均',
#   '有',
#   '出售'],
#  ['大学',
#   '眼药',
#   '如花美眷',
#   '、',
#   '是',
#   '由',
#   '黑白分明',
#   '两只',
#   '眼睛',
#   '发表',
#   '出来',
#   '美貌',
#   '女子',
#   '之',
#   '生命',
#   '、',
#   '系之于',
#   '完全',
#   '之',
#   '眼目',
#   '、',
#   '全',
#   '眼目',
#   '之',
#   '良药',
#   '、',
#   '唯一',
#   '之药',
#   '是',
#   '也',
#   '。',
#   '于',
#   '目疾',
#   '、',
#   '似',
#   '不啻',
#   '夺其生',
#   '一切',
#   '眼病',
#   '之',
#   '良药',
#   '、',
#   '特效',
#   '有',
#   '理想',
#   '发明',
#   '之',
#   '大学',
#   '眼药',
#   '二',
#   '也',
#   '各埠大',
#   '药房',
#   '洋货',
#   '铺',
#   '均',
#   '有',
#   '代售'],
#  ['彼',
#   '急需',
#   '者',
#   '何药',
#   '也',
#   '非',
#   '红色',
#   '清导丸乎',
#   '妇女',
#   '须',
#   '当',
#   '记忆',
#   '凡',
#   '患大',
#   '便秘',
#   '结之症',
#   '能',
#   '使',
#   '月',
#   '事不调',
#   '惟',
#   '服用',
#   '红色',
#   '清导丸',
#   '可以',
#   '疗治',
#   '如能',
#   '使',
#   '大便',
#   '逐日',
#   '畅适',
#   '有序',
#   '则',
#   '面容',
#   '红润',
#   '美丽',
#   '绝无',
#   '红',
#   '瘰',
#   '雀斑',
#   '登患',
#   '发于',
#   '面部',
#   '日免',
#   '须',
#   '疾病',
#   '头痛',
#   '可令',
#   '口气',
#   '芬芳',
#   '是',
#   '以此',
#   '微利',
#   '平肝',
#   '之',
#   '妙品',
#   '须',
#   '常时',
#   '服之可',
#   '也',
#   '京兆',
#   '固安',
#   '高',
#   '小学校',
#   '王六亭',
#   '先生',
#   '来函',
#   '云家',
#   '＊',
#   '＊',
#   '母患',
#   '头痛',
#   '系',
#   '目眩',
#   '今',
#   '春天',
#   '发',
#   '甚至',
#   '面全青',
#   '气绝',
#   '两次',
#   '医药',
#   '无效',
#   '遂服',
#   '红色',
#   '清导丸',
#   '未满',
#   '两瓶',
#   '而',
#   '身体',
#   '康健',
#   '如旧',
#   '且',
#   '处理',
#   '家务',
#   '毫无',
#   '倦容',
#   '皆',
#   '红色',
#   '清导丸',
#   '之功',
#   '红色',
#   '清导丸',
#   '功力',
#   '出自',
#   '天然',
#   '能利',
#   '胆汁',
#   '平',
#   '肝肠',
#   '治',
#   '痔症',
#   '痛苦',
#   '且免',
#   '痢疾',
#   '肠泻',
#   '之',
#   '虞',
#   '凡',
#   '经售',
#   '西药',
#   '者',
#   '均',
#   '有',
#   '出售',
#   '或者',
#   '直',
#   '寄',
#   '邮票',
#   '大洋',
#   '六角',
#   '至',
#   '上海',
#   '四川',
#   '路',
#   '九十六',
#   '号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '原班',
#   '奉',
#   '一瓶',
#   '可',
#   '也'],
#  ['凡',
#   '拉蒙',
#   '能止',
#   '一切',
#   '疼痛',
#   '经来',
#   '疼痛',
#   '请服',
#   '凡',
#   '拉蒙',
#   '各大',
#   '药房',
#   '均',
#   '有',
#   '出售'],
#  ['头痛',
#   '不止',
#   '服',
#   '寻常',
#   '头痛',
#   '药',
#   '无效',
#   '而',
#   '又',
#   '非',
#   '因',
#   '目光',
#   '毛病',
#   '那',
#   '就是',
#   '说不定',
#   '是',
#   '因',
#   '血亏',
#   '以致',
#   '神经衰弱',
#   '的',
#   '原故',
#   '大抵',
#   '治疗',
#   '神经症',
#   '最佳',
#   '之',
#   '法子',
#   '是',
#   '由',
#   '补血',
#   '入手',
#   '如',
#   '头痛',
#   '腰痛',
#   '肢酸',
#   '不眠',
#   '等',
#   '症均',
#   '是',
#   '消化',
#   '病亦有',
#   '狠',
#   '多',
#   '是',
#   '因',
#   '神经衰弱',
#   '故',
#   '亦',
#   '属于',
#   '血亏',
#   '症',
#   '之类',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '补血',
#   '健脑',
#   '之',
#   '功能',
#   '躬自',
#   '试验',
#   '而证',
#   '其良',
#   '效者',
#   '遍',
#   '天下',
#   '数以万计',
#   '盖此',
#   '丸',
#   '所',
#   '含',
#   '之',
#   '成分',
#   '甚易',
#   '吸收',
#   '入血',
#   '使',
#   '血液',
#   '立受',
#   '养化',
#   '于是',
#   '薄者',
#   '稠浊者',
#   '清',
#   '少者',
#   '多',
#   '矣',
#   '举凡',
#   '精力',
#   '衰微',
#   '头痛',
#   '背楚',
#   '腰疼',
#   '目眩',
#   '心跳',
#   '肌瘦性',
#   '爆不眠',
#   '消化不良',
#   '面无血色',
#   '等候',
#   '皆',
#   '因',
#   '血亏',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '皆',
#   '可',
#   '使',
#   '之速',
#   '愈',
#   '南洋',
#   '爪哇',
#   '三实',
#   '垄',
#   '中山',
#   '旅社',
#   '陈君',
#   '孙俊来',
#   '书云',
#   '鄙人',
#   '前',
#   '因',
#   '用脑',
#   '过度',
#   '常患',
#   '头痛',
#   '饮食',
#   '不进',
#   '深恐',
#   '将成',
#   '不治幸',
#   '蒙永大',
#   '和',
#   '药房',
#   '友人',
#   '介绍',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸服',
#   '不多时',
#   '头痛',
#   '全愈',
#   '胃纳',
#   '增强',
#   '体气',
#   '亦',
#   '从',
#   '是',
#   '强健',
#   '矣',
#   '曷',
#   '胜',
#   '感激',
#   '韦廉士',
#   '红色',
#   '补丸',
#   '补血',
#   '健脑',
#   '屡试屡验',
#   '男女',
#   '咸宜',
#   '如',
#   '尊处',
#   '无从',
#   '购买',
#   '可',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '每瓶',
#   '大洋',
#   '一元',
#   '五角',
#   '六瓶',
#   '大洋',
#   '八元',
#   '中国',
#   '境内',
#   '邮费',
#   '不取'],
#  ['白礼氏洋烛',
#   '皆',
#   '认为',
#   '上',
#   '等',
#   '多',
#   '人',
#   '仿效',
#   '总未',
#   '如其',
#   '优胜',
#   '白礼氏洋烛',
#   '得',
#   '天下',
#   '之',
#   '名誉',
#   '因为',
#   '其洋烛',
#   '占',
#   '最',
#   '优等',
#   '系制',
#   '著名',
#   '水牛',
#   '紫薇星',
#   '百合花',
#   '烛者',
#   '曾复',
#   '各国',
#   '赛会',
#   '奖赏',
#   '三十九',
#   '大白',
#   '礼氏洋烛',
#   '公司',
#   '上海',
#   '北京路',
#   '四号'],
#  ['征联',
#   '香港',
#   '利百',
#   '洋行',
#   '红十字',
#   '佛兰地',
#   '酒拟',
#   '联求',
#   '教联首',
#   '（',
#   '身健',
#   '只缘',
#   '觞',
#   '美酒',
#   '）',
#   '佳卷',
#   '*',
#   '呈',
#   '庞策',
#   '云',
#   '老师',
#   '评阅',
#   '共列',
#   '三百名',
#   '首名',
#   '至',
#   '第',
#   '三百名',
#   '奖金',
#   '奖品',
#   '从优',
#   '另招',
#   '开列',
#   '国历',
#   '七月',
#   '底截',
#   '八月',
#   '中',
#   '揭',
#   '暁',
#   '总',
#   '*',
#   '处',
#   '广州市',
#   '上',
#   '陈塘招',
#   '*',
#   '向',
#   '招兰轩',
#   '索取',
#   '香港',
#   '大道',
#   '中',
#   '崋',
#   '人行',
#   '利百',
#   '洋行',
#   '启'],
#  ['因',
#   '克利',
#   '西佛味',
#   '甘易服',
#   '迅治',
#   '各种',
#   '呼吸',
#   '气道',
#   '之',
#   '疾病',
#   '如',
#   '咳嗽',
#   '伤风',
#   '等',
#   '症',
#   '立刻',
#   '杀',
#   '尽',
#   '微菌',
#   '化除',
#   '黏痰',
#   '解除',
#   '痛苦',
#   '克利',
#   '西佛',
#   '价目',
#   '业已',
#   '减低',
#   '拜耳',
#   '十字',
#   '商标',
#   '为',
#   '良药',
#   '之',
#   '明证'],
#  ['精神',
#   '萎顿',
#   '否',
#   '如若',
#   '精力不济',
#   '请',
#   '观世光',
#   '女子',
#   '高等',
#   '小学校',
#   '校长',
#   '黄杰安',
#   '如何',
#   '精神焕发',
#   '也',
#   '无论',
#   '男女',
#   '首贵',
#   '精神',
#   '充足',
#   '其意',
#   '即',
#   '精力',
#   '强固',
#   '神气',
#   '充溢',
#   '脑筋',
#   '有力',
#   '如若',
#   '精力不济',
#   '自觉',
#   '软弱',
#   '脑体',
#   '不安',
#   '胃',
#   '不',
#   '消化',
#   '腰痛',
#   '背楚',
#   '风湿',
#   '骨痛夜',
#   '不',
#   '安睡',
#   '忧郁',
#   '烦闷',
#   '相继',
#   '而作',
#   '矣',
#   '如',
#   '欲',
#   '体力',
#   '充足',
#   '身体',
#   '爽健非',
#   '补血',
#   '健脑',
#   '不为',
#   '功',
#   '补血',
#   '之圣品',
#   '首推',
#   '韦廉士',
#   '大',
#   '医生',
#   '红色',
#   '补丸',
#   '也',
#   '请',
#   '读',
#   '广东',
#   '石歧',
#   '世光',
#   '女子',
#   '高等',
#   '小学校',
#   '校长',
#   '黄杰安',
#   '先生',
#   '之',
#   '证书',
#   '彼',
#   '称赞',
#   '红色',
#   '补丸',
#   '为',
#   '补脑',
#   '之',
#   '生力军',
#   '是',
#   '则',
#   '红色',
#   '补丸',
#   '既',
#   '能',
#   '治愈',
#   '黄君',
#   '之症',
#   '亦可',
#   '治愈',
#   '阁下',
#   '之症',
#   '也',
#   '幸勿',
#   '观望',
#   '迟误',
#   '请',
#   '自',
#   '今日',
#   '始亦为',
#   '购服',
#   '之',
#   '黄君',
#   '来函',
#   '云杰安',
#   '厕身',
#   '教育',
#   '日事丹',
#   '沿',
#   '劳苦',
#   '类',
#   '＊',
#   '积成',
#   '脑病',
#   '购药于',
#   '市百无一效',
#   '友人',
#   '程君大元',
#   '石歧',
#   '中西药',
#   '局',
#   '主人',
#   '也',
#   '送',
#   '予以',
#   '韦廉士',
#   '红色',
#   '补丸',
#   '数瓶',
#   '尝试',
#   '恐有',
#   '吗啡',
#   '在',
#   '其无予',
#   '乃',
#   '姑试',
#   '之',
#   '不觉',
#   '其功',
#   '与',
#   '过',
#   '也',
#   '再',
#   '服之则',
#   '饮食',
#   '渐进',
#   '因连服',
#   '数瓶',
#   '精神焕发',
#   '旧病',
#   '失余始',
#   '信',
#   '红色',
#   '补丸',
#   '功效',
#   '之大',
#   '＊',
#   '＊',
#   '市',
#   '上',
#   '各种',
#   '补药',
#   '之上',
#   '者',
#   '也',
#   '谨志',
#   '数言示',
#   '不',
#   '忘',
#   '焉',
#   '韦廉士',
#   '大',
#   '医生',
#   '红色',
#   '补丸',
#   '凡',
#   '经售',
#   '西药',
#   '者',
#   '均',
#   '有',
#   '出售',
#   '或直',
#   '向',
#   '上海',
#   '四川',
#   '路',
#   '九十六',
#   '号',
#   '韦廉士',
#   '药局',
#   '函购',
#   '每瓶',
#   '中国',
#   '大洋',
#   '一元',
#   '五角',
#   '六瓶',
#   '中国',
#   '大洋',
#   '八元',
#   '邮力',
#   '在内',
#   '精美',
#   '小',
#   '书',
#   '奉送',
#   '函索',
#   '即',
#   '寄',
#   '如患',
#   '脑力',
#   '衰残',
#   '脑筋',
#   '受损',
#   '各症',
#   '者',
#   '寄',
#   '一',
#   '明信片',
#   '至',
#   '以上',
#   '所',
#   '列',
#   '地址',
#   '索取',
#   '韦廉士',
#   '药局',
#   '出版',
#   '小',
#   '书',
#   '名曰',
#   '脑系',
#   '疾病',
#   '一本',
#   '原班',
#   '邮送'],
#  ['白礼氏',
#   '船牌',
#   '洋烛',
#   '看书',
#   '光亮',
#   '清楚',
#   '不损',
#   '目力',
#   '各埠洋',
#   '广货',
#   '店均',
#   '有',
#   '经售',
#   '上海',
#   '白礼氏洋烛',
#   '公司'],
#  ['说',
#   '也',
#   '奇怪',
#   '不论',
#   '天',
#   '热天',
#   '冷',
#   '康健',
#   '人',
#   '的',
#   '体温',
#   '总是',
#   '一成不变',
#   '茍',
#   '有',
#   '变化',
#   '而',
#   '温度',
#   '高于',
#   '九十八',
#   '度半之常度',
#   '即系',
#   '发热',
#   '象征',
#   '务须',
#   '速加',
#   '治理',
#   '韦廉士',
#   '医生',
#   '家用',
#   '良药',
#   '新增',
#   '出品',
#   '纽',
#   '禄丰',
#   '乃',
#   '最',
#   '可靠',
#   '退热药',
#   '之一',
#   '而',
#   '同时',
#   '又',
#   '善止',
#   '与',
#   '热症',
#   '并发',
#   '之',
#   '各种',
#   '疼痛',
#   '是',
#   '故君',
#   '如',
#   '发热',
#   '请试',
#   '服纽',
#   '禄丰',
#   '看其',
#   '退热',
#   '止痛',
#   '复君',
#   '康健',
#   '之',
#   '速效',
#   '为何',
#   '如',
#   '也',
#   '纽',
#   '禄丰',
#   '新式',
#   '止痛药',
#   '担保',
#   '绝对',
#   '纯洁',
#   '不',
#   '含',
#   '任何',
#   '麻醉品',
#   '或',
#   '其他',
#   '有损',
#   '成分',
#   '对于',
#   '退热',
#   '固具',
#   '特长',
#   '即',
#   '对于',
#   '消风散',
#   '寒治',
#   '流行性',
#   '感冒',
#   '及止',
#   '各种',
#   '神经',
#   '肌肉',
#   '疼痛',
#   '亦',
#   '一样',
#   '灵效',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '每瓶',
#   '大洋',
#   '二角',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '一次',
#   '购',
#   '五瓶',
#   '者',
#   '大洋',
#   '一元',
#   '邮力',
#   '不取',
#   '不满',
#   '五瓶',
#   '者',
#   '每瓶',
#   '二角',
#   '邮力',
#   '另加'],
#  ['何必',
#   '忍受',
#   '面疹',
#   '之',
#   '痛苦',
#   '舆耻恶',
#   '面',
#   '痊',
#   '虽仅',
#   '皮肤',
#   '征恙',
#   '但是',
#   '患者',
#   '未免',
#   '日觉',
#   '恶盖',
#   '有损',
#   '观瞻',
#   '生',
#   '然而',
#   '此',
#   '痛苦',
#   '舆',
#   '羞恶',
#   '无',
#   '忍受',
#   '之',
#   '必要',
#   '因为',
#   '现代',
#   '疗肤品',
#   '如意',
#   '膏',
#   '已',
#   '治愈',
#   '面疹',
#   '不可胜数',
#   '如',
#   '山东',
#   '无棣',
#   '北',
#   '闗',
#   '路',
#   '东',
#   '杨家',
#   '店',
#   '杨君',
#   '照',
#   '逺',
#   '即',
#   '其',
#   '最近',
#   '之一',
#   '例',
#   '也',
#   '杨君书云',
#   '鄙人',
#   '曾患',
#   '面部',
#   '小疹',
#   '痛痒',
#   '难耐',
#   '百药',
#   '无效',
#   '后阅',
#   '报知',
#   '如意',
#   '膏之功',
#   '乃',
#   '试涂',
#   '之',
#   '果然',
#   '凉爽',
#   '止痒',
#   '舒服',
#   '异常',
#   '不久',
#   '竟',
#   '全告',
#   '愈',
#   '凡',
#   '亲友',
#   '有患',
#   '疥疮',
#   '毒',
#   '刀割',
#   '等',
#   '症者',
#   '予常',
#   '介绍',
#   '如意',
#   '膏',
#   '亦',
#   '莫不',
#   '奏',
#   '神效',
#   '也',
#   '如意',
#   '膏',
#   '统治',
#   '湿疹',
#   '疥癣',
#   '烂',
#   '腿',
#   '癞头',
#   '疔',
#   '疮',
#   '陈疮折',
#   '脓包',
#   '以及',
#   '灼伤',
#   '烫伤',
#   '跌损',
#   '等',
#   '患',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '每盒',
#   '七角',
#   '六盒',
#   '三元',
#   '五角',
#   '邮费',
#   '不取'],
#  ['血蛇',
#   '恶癣',
#   '救星',
#   '狮标',
#   '那必',
#   '敌血',
#   '毒片',
#   '此药',
#   '行销',
#   '各埠',
#   '十余年',
#   '治愈',
#   '登报',
#   '恭颂者',
#   '指不胜屈',
#   '无论',
#   '血',
#   '毒血',
#   '蛇',
#   '恶癣',
#   '见',
#   '有',
#   '痕痒',
#   '红',
#   '癍',
#   '面热耳红',
#   '皮肉',
#   '浮肿',
#   '虫行',
#   '蚁',
#   '咬',
#   '毛',
#   '髪',
#   '易',
#   '脱',
#   '等',
#   '状',
#   '花柳',
#   '疳',
#   '疔',
#   '各',
#   '穜',
#   '毒症',
#   '及',
#   '皮肤',
#   '疮',
#   '癞',
#   '均',
#   '埽',
#   '灭',
#   '无道',
#   '大',
#   '瓶',
#   '七元',
#   '小瓶',
#   '*',
#   '元',
#   '十八',
#   '甫',
#   '普威',
#   '永汉北',
#   '老威',
#   '太平',
#   '南',
#   '*',
#   '済',
#   '大新',
#   '公司',
#   '先施',
#   '公司',
#   '十七',
#   '甫',
#   '仁寿',
#   '代售',
#   '一德路',
#   '*',
#   '永雄',
#   '*',
#   '所',
#   '发行'],
#  ['美容',
#   '药料',
#   '花颜水',
#   '皮肤',
#   '能',
#   '令人',
#   '外貌',
#   '最易',
#   '*',
#   '变',
#   '虽然',
#   '生成',
#   '美丽',
#   '娇容',
#   '若任',
#   '皮肤',
#   '自成',
#   '粗陋',
#   '非独',
#   '不得',
#   '维持',
#   '原有',
#   '之美',
#   '且',
#   '不能',
#   '发挥',
#   '天性',
#   '之美',
#   '皮肤',
#   '之',
#   '关系',
#   '于',
#   '美丽',
#   '有',
#   '如此',
#   '也',
#   '自古',
#   '世间',
#   '自',
#   '*',
#   '其',
#   '容貌',
#   '丑陋',
#   '者',
#   '实属',
#   '不稀',
#   '此',
#   '又',
#   '人生',
#   '最大',
#   '之',
#   '遗憾',
#   '兹',
#   '有',
#   '日本',
#   '皮肤科',
#   '专门',
#   '大医',
#   '小岛',
#   '先生',
#   '多年',
#   '研究',
#   '自出心裁',
#   '发明',
#   '一种',
#   '良药',
#   '精制',
#   '而成',
#   '美容',
#   '药水',
#   '名曰',
#   '花颜水仅',
#   '以',
#   '数滴',
#   '滴入',
#   '洗脸水',
#   '中',
#   '或融',
#   '溶',
#   '数倍',
#   '至',
#   '清水',
#   '该盆内',
#   '之水',
#   '即逢',
#   '药水',
#   '而',
#   '变色',
#   '如乳',
#   '其馨',
#   '馥郁',
#   '触鼻',
#   '虽',
#   '鲜花',
#   '如',
#   '玫瑰',
#   '与',
#   '兰花',
#   '亦',
#   '退一步',
#   '且合',
#   '卫生',
#   '善治',
#   '皮肤',
#   '所',
#   '发小疮',
#   '如',
#   '面疱',
#   '暗疮',
#   '雀斑',
#   '粉刺',
#   '酒刺',
#   '汗疹',
#   '顽',
#   '廯',
#   '烟气',
#   '红',
#   '点',
#   '油光',
#   '瘰疬',
#   '等',
#   '诸症',
#   '讨厌',
#   '之物',
#   '凡',
#   '老幼',
#   '男女皆可',
#   '使用',
#   '此花',
#   '颜水',
#   '均',
#   '得',
#   '转丑',
#   '成美',
#   '花颜水',
#   '之',
#   '特色',
#   '最能',
#   '完全',
#   '皮肤',
#   '乃',
#   '成色',
#   '使',
#   '姿容',
#   '倍',
#   '极',
#   '光耀',
#   '足称',
#   '最上',
#   '妙品',
#   '请试',
#   '一瓶',
#   '以证本',
#   '药房',
#   '之言',
#   '不谬',
#   '药价',
#   '大',
#   '瓶',
#   '大洋',
#   '一元',
#   '小瓶',
#   '大洋',
#   '五角',
#   '试用',
#   '瓶',
#   '大洋',
#   '三角',
#   '五分'],
#  ['现在',
#   '街上',
#   '发现',
#   '一种',
#   '香烟',
#   '混充',
#   '大',
#   '号',
#   '哈德门',
#   '吸者',
#   '常为',
#   '冒牌',
#   '所',
#   '欺',
#   '今特',
#   '将',
#   '大',
#   '号',
#   '哈德门',
#   '烟样',
#   '画成',
#   '式样',
#   '以示',
#   '真假'],
#  ['利比',
#   '儿',
#   '见效',
#   '绝大',
#   '特制',
#   '利比',
#   '儿',
#   '奏效',
#   '最为',
#   '神速',
#   '现代',
#   '治淋药',
#   '中',
#   '首屈一指',
#   '者',
#   '日本',
#   '内地',
#   '自不',
#   '*',
#   '*',
#   '*',
#   '海外',
#   '诸国',
#   '到处',
#   '*',
#   '不',
#   '*',
#   '*',
#   '*',
#   '大',
#   '之',
#   '信用',
#   '服用',
#   '利比',
#   '儿',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '本剂',
#   '之',
#   '特征',
#   '一',
#   '、',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*'],
#  ['因',
#   '血亏',
#   '不能',
#   '站立',
#   '此',
#   '爪哇',
#   '中国',
#   '音乐家',
#   '竟得',
#   '健康',
#   '全服',
#   '由于',
#   '服用',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '血液',
#   '亏损',
#   '二至',
#   '有时',
#   '不能',
#   '站立',
#   '其',
#   '精力',
#   '衰残',
#   '其',
#   '治疗',
#   '棘手',
#   '已',
#   '可',
#   '概见',
#   '然而',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '补血',
#   '之功',
#   '亦',
#   '复',
#   '神奇',
#   '至',
#   '是',
#   '竟',
#   '能',
#   '恢复',
#   '黄君长',
#   '吉',
#   '之',
#   '健康',
#   '无欠',
#   '无缺',
#   '黄君系',
#   '中国',
#   '音乐',
#   '専',
#   '家',
#   '寓',
#   '爪哇',
#   '泗水',
#   '森末间',
#   '二',
#   '六号',
#   '其来',
#   '书云',
#   '予因',
#   '工作',
#   '娱乐',
#   '均',
#   '有',
#   '过度',
#   '致患',
#   '疾病',
#   '所侵',
#   '动辄',
#   '心跳',
#   '头晕',
#   '易感',
#   '疲乏',
#   '眠',
#   '睡',
#   '不安',
#   '飮',
#   '食',
#   '无味',
#   '有时',
#   '且觉',
#   '不能',
#   '站立',
#   '就诊',
#   '于',
#   '医谓',
#   '系',
#   '血亏',
#   '但',
#   '服药',
#   '未见',
#   '明效',
#   '后试',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '旬日',
#   '即觉',
#   '稍',
#   '瘥',
#   '续',
#   '服',
#   '数',
#   '瓶',
#   '血气',
#   '渐服',
#   '不久',
#   '色旺力',
#   '强',
#   '精神饱满',
#   '从前',
#   '最怕',
#   '入浴',
#   '至此',
#   '又',
#   '能',
#   '照常',
#   '沐浴',
#   '现年',
#   '六十',
#   '隅',
#   '有',
#   '不适',
#   '总不忘',
#   '服用',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '也',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '补血',
#   '健脑',
#   '世界',
#   '驰名',
#   '其',
#   '治疗',
#   '血亏',
#   '各症',
#   '如早',
#   '老食滞',
#   '各',
#   '穜',
#   '痛',
#   '疯脑系',
#   '衰残病',
#   '后',
#   '虚弱',
#   '以及',
#   '妇科',
#   '特症',
#   '已历',
#   '五十',
#   '载',
#   '无',
#   '舆',
#   '伦比',
#   '者',
#   '矣',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '每瓶',
#   '一元',
#   '五角',
#   '六瓶',
#   '八元',
#   '邮费',
#   '不取'],
#  ['婴孩',
#   '自己',
#   '药片',
#   '使',
#   '其',
#   '如此',
#   '康乐',
#   '也',
#   '上海',
#   '商务印书馆',
#   '代表人',
#   '王巧',
#   '先生',
#   '来示',
#   '云',
#   '小',
#   '女王',
#   '秀菊现',
#   '周年',
#   '岁',
#   '另',
#   '一个月',
#   '自',
#   '初生',
#   '以后',
#   '即',
#   '服用',
#   '韦廉士',
#   '婴孩',
#   '自己',
#   '药片',
#   '其',
#   '效验',
#   '之',
#   '神速',
#   '稳妥',
#   '不得不',
#   '称颂',
#   '之',
#   '也',
#   '每届',
#   '便结',
#   '或',
#   '寒热',
#   '感冒',
#   '夜',
#   '不',
#   '安睡',
#   '啼哭',
#   '等',
#   '症',
#   '随时',
#   '取用',
#   '自己',
#   '药片',
#   '一二片',
#   '立即',
#   '见功',
#   '安然无恙',
#   '诚系保',
#   '赤字',
#   '之',
#   '灵丹',
#   '今特',
#   '呈',
#   '小孩',
#   '照片',
#   '请',
#   '登报',
#   '章',
#   '广告',
#   '世之为',
#   '父母',
#   '者',
#   '知所',
#   '效法',
#   '凡',
#   '家中',
#   '有',
#   '小儿',
#   '及',
#   '婴孩',
#   '者',
#   '不能',
#   '不备',
#   '婴孩',
#   '自己',
#   '药片',
#   '一瓶',
#   '于',
#   '家中',
#   '如',
#   '尊处',
#   '无从',
#   '购买',
#   '祈即',
#   '邮寄',
#   '邮票',
#   '大洋',
#   '六角',
#   '至',
#   '上海',
#   '四川',
#   '路',
#   '九十六',
#   '号',
#   '韦廉士',
#   '药局',
#   '原版',
#   '邮奉',
#   '一瓶',
#   '可',
#   '也'],
#  ['驰名',
#   '全球',
#   '之',
#   '‘',
#   '辟得富',
#   '’',
#   '牌',
#   '运输',
#   '汽车',
#   '，',
#   '虽',
#   '为',
#   '英制',
#   '，',
#   '但',
#   '对于',
#   '世界',
#   '各国',
#   '各种',
#   '运输车',
#   '之',
#   '用途',
#   '上',
#   '，',
#   '曾',
#   '加以',
#   '审慎考虑',
#   '，',
#   '故其',
#   '销路',
#   '广大',
#   '。',
#   '有口皆碑',
#   '。',
#   '倘蒙',
#   '惠顾',
#   '，',
#   '无',
#   '任',
#   '欢迎',
#   '。',
#   '此项',
#   '运输',
#   '汽车',
#   '之',
#   '优点',
#   '，',
#   '有如',
#   '下述',
#   '：',
#   '一',
#   '式样',
#   '摩登',
#   '，',
#   '装置',
#   '完备',
#   '。',
#   '二',
#   '机件',
#   '坚强',
#   '，',
#   '使用',
#   '耐久',
#   '。',
#   '三',
#   '马力',
#   '巨大',
#   '，',
#   '行驶',
#   '快捷',
#   '。',
#   '四',
#   '登上',
#   '爬岭',
#   '，',
#   '如履平地',
#   '。',
#   '五',
#   '节省',
#   '汽油',
#   '，',
#   '极为',
#   '经济',
#   '。',
#   '六',
#   '定价',
#   '低廉',
#   '，',
#   '从来未有',
#   '。'],
#  ['其愈',
#   '可立',
#   '而',
#   '待',
#   '君如',
#   '偶尔',
#   '割伤',
#   '跌损',
#   '擦伤',
#   '抓伤',
#   '汤火',
#   '烫伤',
#   '或',
#   '生疮',
#   '肿毒',
#   '溃烂',
#   '生脓',
#   '切勿',
#   '妄用',
#   '蛛网',
#   '灰尘',
#   '烟油',
#   '墨汁',
#   '等类',
#   '俗药',
#   '因其害',
#   '多益',
#   '少',
#   '也',
#   '凡遇',
#   '此项',
#   '皮伤',
#   '皮病',
#   '但',
#   '搽',
#   '如意',
#   '膏',
#   '其',
#   '愈',
#   '莫',
#   '不可',
#   '立而待良',
#   '以此',
#   '膏',
#   '乃',
#   '最新',
#   '科学',
#   '疗肤',
#   '专品',
#   '其',
#   '清凉',
#   '止痛',
#   '解毒',
#   '生肌',
#   '之功',
#   '均',
#   '能',
#   '奏效',
#   '于',
#   '俄顷',
#   '江苏',
#   '南通',
#   '双桥镇',
#   '通生祥',
#   '主人',
#   '云',
#   '[',
#   '年',
#   '来',
#   '鄙人',
#   '常患',
#   '各种',
#   '皮病',
#   '屡治屡',
#   '发近',
#   '搽',
#   '如意',
#   '膏',
#   '功效',
#   '大异',
#   '立觉',
#   '止痛',
#   '清凉',
#   '搽',
#   '用',
#   '无几',
#   '一切',
#   '皮病',
#   '竟',
#   '不',
#   '复发',
#   '矣',
#   '因此',
#   '鄙',
#   '甚',
#   '赞成',
#   '此',
#   '药膏',
#   '也',
#   ']',
#   '如意',
#   '膏',
#   '各',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '或直',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '壹一',
#   '号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '每盒',
#   '七角',
#   '六盒',
#   '三元',
#   '五角',
#   '邮费',
#   '不取'],
#  ['"',
#   'GRADUATE',
#   'OPTICIAN',
#   '"',
#   ',',
#   '"',
#   '中国',
#   '最',
#   '进步',
#   '之',
#   '眼光',
#   '学家',
#   '"',
#   ',',
#   '"',
#   '诸君',
#   '如欲购',
#   '最合光',
#   '最新',
#   '式',
#   '最',
#   '可靠',
#   '之',
#   '眼镜',
#   '请',
#   '至',
#   '本',
#   '公司',
#   '或',
#   '分公司',
#   '一试',
#   '"'],
#  ['红崩',
#   '白带',
#   '子宫炎',
#   '子宫',
#   '糜烂',
#   '子宫',
#   '恶臭',
#   '子宫',
#   '搔痒',
#   '尿意',
#   '频促',
#   '月经',
#   '前后',
#   '疼痛',
#   '及其',
#   '他',
#   '穜',
#   '妇人',
#   '生殖器',
#   '疾患'],
#  ['此即',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '是',
#   '也',
#   '当此',
#   '药片',
#   '在',
#   '口',
#   '缓化',
#   '溶化',
#   '之际',
#   '立即',
#   '挥发',
#   '高度',
#   '的',
#   '芬芳',
#   '治疗',
#   '气体',
#   '直入',
#   '鼻道',
#   '气管',
#   '肺部',
#   '于是',
#   '气管',
#   '清痰',
#   '炎膜',
#   '滋润',
#   '痰化',
#   '喘',
#   '传平播',
#   '此',
#   '种种',
#   '呼吸器',
#   '病',
#   '之',
#   '病菌',
#   '绝灭',
#   '矣',
#   '江苏',
#   '镇江',
#   '姚家',
#   '桥',
#   '基督教',
#   '会',
#   '徐',
#   '良士',
#   '君来',
#   '书云',
#   '鄙人',
#   '久',
#   '患',
#   '咳嗽',
#   '屡服',
#   '各药',
#   '皆',
#   '未',
#   '见效',
#   '但',
#   '试服',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片后',
#   '不久',
#   '即告',
#   '痊愈',
#   '矣',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '奏效',
#   '较',
#   '一切',
#   '咳',
#   '药水',
#   '咳',
#   '药丸',
#   '为速者',
#   '因其能',
#   '直接',
#   '以气',
#   '薰',
#   '治病',
#   '原故',
#   '也',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '大',
#   '瓶',
#   '每瓶',
#   '大洋',
#   '七角',
#   '无缝',
#   '小瓶',
#   '六角',
#   '邮力',
#   '不取'],
#  ['无往', '而', '非大', '炮台', '吸者', '另', '有', '三', '炮台', '出售'],
#  ['不仅',
#   '美食',
#   '丰衣',
#   '奉养',
#   '序母',
#   '必',
#   '也',
#   '使',
#   '其',
#   '心悦神怡',
#   '庶乎',
#   '得',
#   '之此',
#   '古哲教',
#   '人事',
#   '亲之道',
#   '也',
#   '在',
#   '许多',
#   '人',
#   '子',
#   '当中',
#   '周君',
#   '宝林',
#   '显然',
#   '是',
#   '能',
#   '体此',
#   '古训',
#   '以事',
#   '其',
#   '母者',
#   '也',
#   '下录',
#   '周君来',
#   '书',
#   '请试',
#   '一阅',
#   '便',
#   '知其',
#   '如何',
#   '奉母',
#   '也',
#   '周君前',
#   '红',
#   '兵站',
#   '军需官',
#   '现寓',
#   '山西太原',
#   '府',
#   '新民路',
#   '八十一',
#   '号',
#   '其',
#   '*',
#   '客云',
#   '家母',
#   '因昔',
#   '操劳过度',
#   '年',
#   '来',
#   '身体',
#   '不佳',
#   '每觉',
#   '愁闷',
#   '其',
#   '症系',
#   '气血',
#   '两亏',
#   '面黄肌瘦',
#   '腰背痛',
#   '楚',
#   '头目',
#   '晕眩',
#   '寝',
#   '不安',
#   '食',
#   '不甘',
#   '全',
#   '*',
#   '*',
#   '觉',
#   '软弱',
#   '遍药',
#   '无效',
#   '未免',
#   '焦灼',
#   '后由友',
#   '介绍',
#   '服用',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '兼服',
#   '清导丸',
#   '随觉',
#   '食',
#   '增力益续',
#   '服',
#   '无几',
#   '诸症',
#   '霍然',
#   '现在',
#   '家母',
#   '又',
#   '十分',
#   '康强',
#   '喜乐',
#   '矣',
#   '因奉',
#   '其',
#   '肖以志',
#   '谢忱',
#   '焉',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '补血',
#   '健脑',
#   '天下',
#   '驰名',
#   '凡患',
#   '血亏',
#   '而',
#   '起',
#   '之',
#   '各症',
#   '无论',
#   '男女老幼',
#   '均',
#   '已',
#   '屡',
#   '奏',
#   '神效',
#   '矣',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '每瓶',
#   '一元',
#   '五角',
#   '六瓶',
#   '八元',
#   '邮费',
#   '不取'],
#  ['阁下',
#   '小孩',
#   '如患',
#   '咳嗽',
#   '伤风',
#   '或',
#   '喉痛',
#   '而',
#   '又',
#   '能口',
#   '含',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片者',
#   '请',
#   '用',
#   '此片',
#   '治之勿用',
#   '仅',
#   '能',
#   '吞咽',
#   '入胃',
#   '之',
#   '咳乐良',
#   '以',
#   '各该',
#   '症起',
#   '原于',
#   '呼吸器',
#   '而',
#   '呼吸器',
#   '者',
#   '惟',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '之',
#   '治疗',
#   '气体',
#   '乃',
#   '能',
#   '达到',
#   '也',
#   '请',
#   '一试',
#   '而',
#   '证实',
#   '之',
#   '亦',
#   '犹',
#   '广东',
#   '恩平',
#   '邮局',
#   '崔棣华君来',
#   '书云',
#   '三',
#   '小儿',
#   '会',
#   '苏近',
#   '感',
#   '风寒',
#   '日夜',
#   '咳嗽',
#   '气喘',
#   '身热',
#   '夜眠',
#   '不安',
#   '当即',
#   '给与',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '数枚',
#   '含',
#   '之',
#   '当晚',
#   '即得',
#   '安眠',
#   '翌晨',
#   '咳止',
#   '痰',
#   '消诸',
#   '症悉',
#   '愈',
#   '矣',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '治疗',
#   '咳嗽',
#   '伤风',
#   '喉痛',
#   '气喘',
#   '气管',
#   '支炎',
#   '以及',
#   '其他',
#   '气管',
#   '疾患',
#   '系由其',
#   '芬芳',
#   '爽适',
#   '灭菌',
#   '治疗',
#   '之',
#   '气体',
#   '直入',
#   '呼吸器官',
#   '全部',
#   '此',
#   '气体',
#   '乃',
#   '此片',
#   '在',
#   '口中',
#   '溶化',
#   '时所',
#   '挥发',
#   '者',
#   '也',
#   '各大',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '大瓶',
#   '每瓶',
#   '七角',
#   '五分',
#   '小瓶',
#   '六角',
#   '邮力',
#   '不取'],
#  ['友人',
#   '曾',
#   '劝余弟',
#   '亟须',
#   '服用',
#   '韦廉士',
#   '大',
#   '医生',
#   '红色',
#   '补丸',
#   '疗治',
#   '彼',
#   '之',
#   '咳嗽',
#   '其弟',
#   '咳嗽',
#   '治愈',
#   '咳嗽',
#   '为',
#   '患',
#   '最剧',
#   '谚云久',
#   '咳成',
#   '痨',
#   '不可不',
#   '愼',
#   '如',
#   '遇',
#   '咳嗽',
#   '急宜',
#   '疗治',
#   '勿',
#   '延时',
#   '日为',
#   '要',
#   '江西',
#   '南昌',
#   '省长',
#   '公署',
#   '教育',
#   '科科长',
#   '马庆',
#   '龙君',
#   '为',
#   '其',
#   '令弟',
#   '云生',
#   '咳嗽',
#   '治',
#   '痊特书此',
#   '证明',
#   '是',
#   '丸',
#   '之',
#   '功效',
#   '俾得',
#   '患同',
#   '病者',
#   '知所',
#   '问津',
#   '为',
#   '其来',
#   '示云余弟',
#   '云生',
#   '*',
#   '就',
#   '馆务',
#   '他',
#   '省',
#   '今春',
#   '来',
#   '赣',
#   '特留',
#   '之',
#   '俾助',
#   '余',
#   '办公',
#   '不意',
#   '水土不服',
#   '时患',
#   '咳嗽',
#   '医生',
#   '诊视',
#   '亦',
#   '复',
#   '不少',
#   '均',
#   '无',
#   '效验',
#   '后',
#   '有',
#   '友人',
#   '劝服',
#   '韦廉士',
#   '大',
#   '医生',
#   '红色',
#   '补丸',
#   '余',
#   '以为',
#   '看医',
#   '吃药',
#   '尚无',
#   '功效',
#   '何况',
#   '区区',
#   '丸药',
#   '哉',
#   '然余弟',
#   '因盼',
#   '病愈',
#   '心切',
#   '强余购',
#   '之',
#   '不得已',
#   '向',
#   '洗马池',
#   '中华',
#   '药房',
#   '购得',
#   '两瓶',
#   '暂为',
#   '试服',
#   '讵',
#   '知服',
#   '后',
#   '弟病',
#   '日见',
#   '起色',
#   '再',
#   '服半打',
#   '其病',
#   '尽',
#   '去',
#   '矣',
#   '不料',
#   '红色',
#   '补丸',
#   '功效',
#   '有如',
#   '是',
#   '之大者',
#   '真',
#   '救世',
#   '之',
#   '良药',
#   '也',
#   '特',
#   '*',
#   '数行',
#   '以告',
#   '同胞',
#   '盍',
#   '请',
#   '诸君',
#   '试之可',
#   '也',
#   '余言',
#   '非谬',
#   '也',
#   '韦廉士',
#   '大',
#   '医生',
#   '红色',
#   '补丸',
#   '每服',
#   '一丸',
#   '即',
#   '能生',
#   '鲜红',
#   '稠',
#   '浓之新血',
#   '曾经',
#   '以所生',
#   '之',
#   '新血',
#   '疗治',
#   '无数',
#   '之患',
#   '以下',
#   '各症',
#   '者',
#   '即',
#   '如',
#   '疯',
#   '湿骨痛',
#   '臀',
#   '尻',
#   '酸楚',
#   '腰背',
#   '疼痛',
#   '筋系',
#   '剧痛',
#   '血薄',
#   '气衰',
#   '诸虞百损',
#   '胃',
#   '不',
#   '消化',
#   '干湿',
#   '癣',
#   '癞',
#   '皮肤',
#   '诸恙',
#   '山岚',
#   '瘴',
#   '疟',
#   '以及',
#   '妇科',
#   '疑难',
#   '各症',
#   '是',
#   '也',
#   '购者',
#   '须',
#   '注意',
#   '真正',
#   '韦廉士',
#   '大',
#   '医生',
#   '红色',
#   '补丸',
#   '方能',
#   '治病',
#   '已',
#   '曾',
#   '行世',
#   '三十余年',
#   '矣',
#   '并非',
#   '别',
#   '穜',
#   '冒称',
#   '之',
#   '红色',
#   '补丸',
#   '也',
#   '凡',
#   '经售',
#   '西药',
#   '者',
#   '均',
#   '有',
#   '出售',
#   '或直',
#   '向',
#   '上海',
#   '四川',
#   '路',
#   '九十六',
#   '号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '亦可',
#   '每',
#   '一瓶',
#   '英洋',
#   '一元',
#   '五角',
#   '每',
#   '六瓶',
#   '英洋',
#   '八元',
#   '邮力',
#   '在内',
#   '奉送',
#   '小书兹',
#   '有',
#   '精美',
#   '小',
#   '书',
#   '名曰',
#   '血',
#   '之',
#   '疾病',
#   '如欲',
#   '索取',
#   '即须',
#   '寄',
#   '一',
#   '明信片',
#   '至',
#   '敝',
#   '局',
#   '可',
#   '也',
#   '原班',
#   '邮奉'],
#  ['临渊羡鱼',
#   '不如',
#   '退而结网',
#   '临渊羡鱼',
#   '不可',
#   '得',
#   '羡',
#   '亦',
#   '何益',
#   '凡因',
#   '皮病',
#   '损其',
#   '风姿',
#   '而徒',
#   '羡慕',
#   '他人',
#   '之美者',
#   '亦',
#   '犹',
#   '是',
#   '耳',
#   '然而',
#   '人',
#   '人均',
#   '可',
#   '保有',
#   '固有',
#   '之',
#   '风姿',
#   '者',
#   '若',
#   '用',
#   '如意',
#   '膏除',
#   '其皮',
#   '患如面',
#   '诊酒',
#   '刺癣',
#   '疮',
#   '疖',
#   '肿',
#   '或',
#   '其他',
#   '有损',
#   '观之',
#   '毛病',
#   '广东',
#   '福旺',
#   '连兴',
#   '号',
#   '谢天庚',
#   '君来',
#   '书云去',
#   '春',
#   '鄙人',
#   '面',
#   '生疮',
#   '疖碍',
#   '观瞻',
#   '不惟',
#   '斯文',
#   '丧尽',
#   '而且',
#   '痛痒',
#   '非常',
#   '迭',
#   '治疗',
#   '具无',
#   '效验',
#   '自',
#   '以为',
#   '此',
#   '穜',
#   '恶疾',
#   '无法',
#   '治疗',
#   '矣',
#   '幸后',
#   '忆及',
#   '如意',
#   '膏效',
#   '如',
#   '桴',
#   '鼓乃试',
#   '擦',
#   '之',
#   '疖',
#   '立',
#   '瘥',
#   '续',
#   '擦',
#   '不久',
#   '即告',
#   '全愈',
#   '鄙人',
#   '今日',
#   '得',
#   '能',
#   '恢复',
#   '昔日',
#   '容颜',
#   '者',
#   '悉',
#   '出自',
#   '如意',
#   '膏',
#   '所',
#   '赐',
#   '也',
#   '如意',
#   '膏系',
#   '最新',
#   '医药',
#   '科学',
#   '产品',
#   '统治',
#   '湿疹',
#   '疥癣',
#   '*',
#   '*',
#   '烂',
#   '腿',
#   '疮',
#   '伤',
#   '割破',
#   '灼伤',
#   '烫伤',
#   '跌',
#   '损虫',
#   '螫',
#   '抓伤',
#   '擦伤',
#   '面疹',
#   '酒',
#   '刺',
#   '脓疱',
#   '疖肿',
#   '等',
#   '各大',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '或直',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '每盒',
#   '七角',
#   '六盒',
#   '三元',
#   '五角',
#   '邮力',
#   '不取'],
#  ['美容',
#   '药料',
#   '花颜水',
#   '皮肤',
#   '能',
#   '令人',
#   '外貌',
#   '最易',
#   '*',
#   '变',
#   '虽然',
#   '生成',
#   '美丽',
#   '娇容',
#   '若任',
#   '皮肤',
#   '自成',
#   '粗陋',
#   '非独',
#   '不得',
#   '维持',
#   '原有',
#   '之美',
#   '且',
#   '不能',
#   '发挥',
#   '天性',
#   '之美',
#   '皮肤',
#   '之',
#   '关系',
#   '于',
#   '美丽',
#   '有',
#   '如此',
#   '也',
#   '自古',
#   '世间',
#   '自',
#   '*',
#   '其',
#   '容貌',
#   '丑陋',
#   '者',
#   '实属',
#   '不稀',
#   '此',
#   '又',
#   '人生',
#   '最大',
#   '之',
#   '遗憾',
#   '兹',
#   '有',
#   '日本',
#   '皮肤科',
#   '专门',
#   '大医',
#   '小岛',
#   '先生',
#   '多年',
#   '研究',
#   '自出心裁',
#   '发明',
#   '一种',
#   '良药',
#   '精制',
#   '而成',
#   '美容',
#   '药水',
#   '名曰',
#   '花颜水仅',
#   '以',
#   '数滴',
#   '滴入',
#   '洗脸水',
#   '中',
#   '或融',
#   '溶',
#   '数倍',
#   '至',
#   '清水',
#   '该盆内',
#   '之水',
#   '即逢',
#   '药水',
#   '而',
#   '变色',
#   '如乳',
#   '其馨',
#   '馥郁',
#   '触鼻',
#   '虽',
#   '鲜花',
#   '如',
#   '玫瑰',
#   '与',
#   '兰花',
#   '亦',
#   '退一步',
#   '且合',
#   '卫生',
#   '善治',
#   '皮肤',
#   '所',
#   '发小疮',
#   '如',
#   '面疱',
#   '暗疮',
#   '雀斑',
#   '粉刺',
#   '酒刺',
#   '汗疹',
#   '顽',
#   '廯',
#   '烟气',
#   '红',
#   '点',
#   '油光',
#   '瘰疬',
#   '等',
#   '诸症',
#   '讨厌',
#   '之物',
#   '凡',
#   '老幼',
#   '男女皆可',
#   '使用',
#   '此花',
#   '颜水',
#   '均',
#   '得',
#   '转丑',
#   '成美',
#   '花颜水',
#   '之',
#   '特色',
#   '最能',
#   '完全',
#   '皮肤',
#   '乃',
#   '成色',
#   '使',
#   '姿容',
#   '倍',
#   '极',
#   '光耀',
#   '足称',
#   '最上',
#   '妙品',
#   '请试',
#   '一瓶',
#   '以证本',
#   '药房',
#   '之言',
#   '不谬',
#   '药价',
#   '大',
#   '瓶',
#   '大洋',
#   '一元',
#   '小瓶',
#   '大洋',
#   '五角',
#   '试用',
#   '瓶',
#   '大洋',
#   '三角',
#   '五分'],
#  ['购买',
#   '汽车',
#   '者',
#   '，',
#   '莫不',
#   '欲',
#   '机件',
#   '坚固',
#   '，',
#   '样式',
#   '玲珑',
#   '，',
#   '装璜',
#   '美丽',
#   '，',
#   '驾驶',
#   '迅速',
#   '。',
#   '然',
#   '以往',
#   '各种',
#   '汽车',
#   '皆',
#   '有',
#   '美中不足',
#   '之',
#   '处',
#   '，',
#   '欲求',
#   '其',
#   '样样',
#   '称心',
#   '，',
#   '万美',
#   '俱备',
#   '，',
#   '则',
#   '只有',
#   '一九三三年',
#   '式',
#   '之',
#   '新',
#   '‘',
#   '别克',
#   '’',
#   '八',
#   '汽缸',
#   '一牌',
#   '耳',
#   '。',
#   '盖',
#   '此种',
#   '汽车',
#   '为经',
#   '二十九年',
#   '研究所',
#   '得',
#   '之',
#   '结晶',
#   '，',
#   '无美',
#   '不备',
#   '，',
#   '诚为',
#   '今世',
#   '之',
#   '华贵',
#   '珍品',
#   '也',
#   '。',
#   '凡',
#   '有力',
#   '购',
#   '汽车',
#   '者',
#   '，',
#   '而',
#   '不备',
#   '新',
#   '‘',
#   '别克',
#   '’',
#   '一辆',
#   '，',
#   '当为',
#   '莫大',
#   '憾事',
#   '。',
#   '果如',
#   '不信',
#   '，',
#   '请',
#   '驾临',
#   '敝行',
#   '样子',
#   '间',
#   '一视',
#   '，',
#   '便知',
#   '此言',
#   '之',
#   '不',
#   '诬',
#   '矣',
#   '！'],
#  ['如何是好',
#   '大抵',
#   '为',
#   '父母',
#   '者',
#   '往往',
#   '因',
#   '婴孩',
#   '有',
#   '疾',
#   '不知',
#   '如何是好',
#   '手足无措',
#   '惟有',
#   '相对',
#   '饮',
#   '*',
#   '涕泪滂沱',
#   '而已',
#   '敝局',
#   '即',
#   '有',
#   '精美',
#   '小',
#   '书',
#   '一本',
#   '名曰',
#   '保赤',
#   '妙诀',
#   '凡',
#   '购买',
#   '敝局',
#   '婴孩',
#   '自己',
#   '药片',
#   '一瓶',
#   '者',
#   '即可',
#   '奉送',
#   '此书',
#   '一本',
#   '内容',
#   '丰富',
#   '有益于',
#   '为',
#   '母者殊',
#   '非浅',
#   '鲜如有',
#   '无可如何',
#   '之际',
#   '阅',
#   '此书',
#   '可免',
#   '危险',
#   '解决',
#   '疑难',
#   '也',
#   '婴孩',
#   '自己',
#   '药片',
#   '系',
#   '英国',
#   '小孩',
#   '之',
#   '霊',
#   '药',
#   '自',
#   '婴儿',
#   '初生',
#   '至',
#   '孩童',
#   '止',
#   '一切',
#   '寻常',
#   '疾病',
#   '均',
#   '可',
#   '疗治',
#   '即',
#   '如',
#   '发热',
#   '便闭',
#   '回虫',
#   '肚痛',
#   '腹泻',
#   '惊风',
#   '胃酸',
#   '胃',
#   '不',
#   '消化',
#   '以及',
#   '出牙',
#   '各症',
#   '是',
#   '也',
#   '因此',
#   '药片',
#   '能',
#   '使',
#   '小儿',
#   '天然',
#   '安睡',
#   '并',
#   '使',
#   '胃口',
#   '增进',
#   '俾',
#   '小儿',
#   '循序',
#   '长大',
#   '也',
#   '其',
#   '药性',
#   '清洁',
#   '和平',
#   '*',
#   '垢',
#   '可保',
#   '绝无',
#   '危害',
#   '损伤',
#   '之品',
#   '摒除',
#   '一切',
#   '麻醉性',
#   '各药',
#   '*',
#   '难',
#   '其中',
#   '*',
#   '婴孩',
#   '自己',
#   '药片',
#   '凡',
#   '经售',
#   '西药',
#   '者',
#   '均',
#   '有',
#   '出售',
#   '或直',
#   '向',
#   '上海',
#   '四川',
#   '路',
#   '九十六',
#   '号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '每',
#   '一瓶',
#   '英洋',
#   '六角',
#   '邮力',
#   '在内'],
#  ['吸烟',
#   '既',
#   '已',
#   '成瘾',
#   '很难',
#   '革除',
#   '吸烟',
#   '如果',
#   '过度',
#   '喉患',
#   '亦',
#   '每',
#   '难免',
#   '然则',
#   '只有',
#   '戒烟',
#   '或',
#   '忍痛',
#   '两',
#   '途径',
#   '乎',
#   '曰',
#   '否',
#   '无须',
#   '戒烟',
#   '亦',
#   '无须',
#   '忍痛',
#   '许多',
#   '人',
#   '已',
#   '发现',
#   '得',
#   '手舞足蹈',
#   '只要',
#   '于',
#   '吸烟',
#   '后口',
#   '含',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '一枚',
#   '聴',
#   '其',
#   '缓缓',
#   '溶化',
#   '于',
#   '舌',
#   '上',
#   '便',
#   '可',
#   '消解',
#   '烟草',
#   '激喉',
#   '之',
#   '患',
#   '而',
#   '无碍',
#   '于',
#   '吸烟',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片味',
#   '美气芬',
#   '对于',
#   '喉间',
#   '发炎',
#   '之膜',
#   '衣有',
#   '立能',
#   '滋润',
#   '之效',
#   '此片',
#   '在',
#   '口',
#   '溶化',
#   '立即',
#   '挥发',
#   '一',
#   '穜',
#   '芬芳',
#   '药气入',
#   '鼻观',
#   '下',
#   '咽喉',
#   '进气管',
#   '而',
#   '逹',
#   '于',
#   '肺',
#   '其',
#   '固体',
#   '药质',
#   '又',
#   '随口',
#   '涎',
#   '缓流',
#   '喉际',
#   '而',
#   '止痛',
#   '焉',
#   '韦廉士',
#   '吸入',
#   '止咳',
#   '片',
#   '统治',
#   '咳嗽',
#   '伤风',
#   '喉痛',
#   '支气管炎',
#   '气喘',
#   '一切',
#   '胸喉',
#   '疾患',
#   '故',
#   '对于',
#   '不',
#   '吸烟者',
#   '亦',
#   '甚',
#   '有益',
#   '也',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '每大瓶',
#   '七角',
#   '五分',
#   '小瓶',
#   '六角',
#   '邮力',
#   '不取'],
#  ['第',
#   '威德',
#   '消毒',
#   '松香',
#   '膏此膏',
#   '能',
#   '使',
#   '肌肤',
#   '润滑',
#   '并',
#   '能速',
#   '愈',
#   '一切',
#   '皮肤病',
#   '如初',
#   '刀伤',
#   '受创',
#   '水火',
#   '烫伤',
#   '黄水疮',
#   '班痣',
#   '毒疮',
#   '热癣',
#   '风癣',
#   '虫',
#   '刺烂',
#   '腿',
#   '及',
#   '关于',
#   '皮肤',
#   '诸症',
#   '莫不',
#   '药到病除',
#   '为',
#   '今日',
#   '最有',
#   '价值',
#   '之',
#   '皮肤',
#   '灵药',
#   '价目',
#   '大盒',
#   '一元',
#   '五角',
#   '小盒',
#   '六角',
#   '大六盒',
#   '八元',
#   '小六盒',
#   '三元',
#   '邮费',
#   '在内'],
# ...
#   '饮',
#   '半个',
#   '月',
#   '后',
#   ',',
#   '将',
#   '身体',
#   '一秤',
#   ',',
#   '定必',
#   '重过',
#   '旧时',
#   '多',
#   ',',
#   '诚',
#   '以此',
#   '酒经',
#   '英法德',
#   '美',
#   '各国',
#   '医生',
#   '证明',
#   ',',
#   '为',
#   '天下第一',
#   '补品',
#   ',',
#   '妇科',
#   '更为',
#   '奇效',
#   '省佛',
#   '港澳',
#   '酒店',
#   '酒楼',
#   '公司',
#   '办馆',
#   '均',
#   '有',
#   '发售'],
#  ['保定',
#   '府',
#   '西街',
#   '亨得利',
#   '钟表',
#   '行',
#   '郑君元禄',
#   '日前',
#   '寄下',
#   '其',
#   '公子',
#   '像片',
#   '一帧',
#   '随',
#   '又',
#   '接其',
#   '来函',
#   '一道',
#   '略谓',
#   '“',
#   '小儿',
#   '安芳',
#   '现年',
#   '五岁',
#   '体质',
#   '孱弱',
#   '常患',
#   '食积',
#   '便闭',
#   '肌',
#   '瘦',
#   '面黄',
#   '鄙人',
#   '深',
#   '以为',
#   '虑',
#   '幸承',
#   '至友',
#   '厉厚志君',
#   '介绍',
#   '婴孩',
#   '自己',
#   '药片',
#   '当购',
#   '一瓶',
#   '兴伊试',
#   '服果',
#   '得',
#   '胃强',
#   '便',
#   '顺',
#   '百病',
#   '俱消',
#   '现在',
#   '身体',
#   '日见',
#   '肥壮',
#   '足证',
#   '该',
#   '药片',
#   '真',
#   '孩儿',
#   '圣药',
#   '也',
#   '不胜感激',
#   '之',
#   '至',
#   '”',
#   '孩儿',
#   '自己',
#   '药片',
#   '系为',
#   '小儿',
#   '特制',
#   '之奇药',
#   '故效',
#   '大而性',
#   '和',
#   '功宏而味',
#   '美',
#   '统治',
#   '小儿',
#   '发热',
#   '便秘',
#   '食积',
#   '腹痛',
#   '呕吐',
#   '泄泻',
#   '伤风',
#   '痰厥',
#   '出牙',
#   '蛔虫',
#   '等',
#   '症',
#   '价目',
#   '每瓶',
#   '六角',
#   '六瓶',
#   '三元',
#   '邮费',
#   '免收'],
#  ['眼痛',
#   '之',
#   '科学',
#   '的',
#   '舆',
#   '卫生',
#   '的',
#   '治疗',
#   '眼痛',
#   '不可',
#   '忽视',
#   '更',
#   '不可',
#   '治以',
#   '不',
#   '卫生',
#   '之',
#   '方法',
#   '兜安氏',
#   '眼痛',
#   '药膏',
#   '系',
#   '名医',
#   '发明',
#   '为',
#   '眼疾',
#   '之',
#   '科学',
#   '的',
#   '卫生',
#   '的',
#   '药品',
#   '眼痛眼',
#   '赤及',
#   '各',
#   '穜',
#   '眼疾',
#   '擦',
#   '必',
#   '奏效',
#   '各埠',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '上海',
#   '兜安氏',
#   '西药',
#   '公司',
#   '启'],
#  ['皮肤病',
#   '合并症',
#   '如意',
#   '膏',
#   '治愈',
#   '之',
#   '江苏',
#   '南京',
#   '陶',
#   '吴镇',
#   '俞君光',
#   '均',
#   '来',
#   '书云',
#   '“',
#   '鄙人',
#   '面部',
#   '发生',
#   '小酒',
#   '刺小疮',
#   ',',
#   '腿部',
#   '又',
#   '患',
#   '顽癣',
#   '.',
#   '诸药',
#   '无效',
#   '.',
#   '后',
#   '由',
#   '友人',
#   '陈君',
#   '介绍',
#   '搽',
#   '用',
#   '如意',
#   '膏',
#   '.',
#   '未及',
#   '数旬',
#   ',',
#   '两患',
#   '均',
#   '愈',
#   '*',
#   '*',
#   '不患',
#   '任何',
#   '皮病',
#   '.',
#   '实深',
#   '感激',
#   '该',
#   '药膏',
#   '之',
#   '神效',
#   '也',
#   '如意',
#   '膏',
#   '最新',
#   '科学',
#   '疗肤',
#   '专药',
#   '为',
#   '韦廉士',
#   '医生',
#   '药局',
#   '药剂',
#   '专家',
#   '所',
#   '配制',
#   ',',
#   '消毒',
#   '力强',
#   '却',
#   '又',
#   '清凉',
#   '止痛',
#   ',',
#   '迅速',
#   '生肌',
#   ',',
#   '凡',
#   '湿疹',
#   '疥癣',
#   '烂',
#   '脚',
#   '癞头',
#   '割破',
#   '烫伤',
#   '跌',
#   '损虫',
#   '蛰',
#   ',',
#   '以及',
#   '面疹',
#   '酒',
#   '刺',
#   '等',
#   '患均',
#   '善治',
#   '之',
#   '.',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或直',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '壹号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '.',
#   '每盒',
#   '七角',
#   ',',
#   '六盒',
#   '三'],
#  ['打倒',
#   '眼不见为净',
#   '之',
#   '观念',
#   '眼不见为净',
#   '之',
#   '观念',
#   '乃',
#   '危险',
#   '之',
#   '观念',
#   '也',
#   '而',
#   '在',
#   '此',
#   '病菌',
#   '活动',
#   '肠疾',
#   '流行',
#   '之暑',
#   '季为',
#   '尤甚',
#   '焉君',
#   '如',
#   '希望',
#   '平安',
#   '过夏务要',
#   '不时',
#   '预服',
#   '清导丸',
#   '俾',
#   '内腑',
#   '活泼',
#   '大解时',
#   '*',
#   '则',
#   '偶尔',
#   '飮',
#   '食',
#   '不',
#   '甚',
#   '卫生',
#   '之物',
#   '亦',
#   '能',
#   '迅速',
#   '排除',
#   '不留',
#   '为害',
#   '此丸系',
#   '最新',
#   '医药',
#   '科学',
#   '之',
#   '产品',
#   '在',
#   '润肠',
#   '药物',
#   '场中',
#   '可算',
#   '鹤立鸡群',
#   '不同',
#   '凡品',
#   '效大性',
#   '和',
#   '绝无',
#   '绞痛',
#   '成瘾',
#   '诸弊',
#   '举凡',
#   '头疼',
#   '肚火',
#   '口苦',
#   '口臭',
#   '胆汁',
#   '不',
#   '调',
#   '以及',
#   '一切',
#   '肠胃',
#   '失序',
#   '之',
#   '毛病',
#   '均',
#   '善治',
#   '之间',
#   '当',
#   '吞服',
#   '一二',
#   '且',
#   '可防',
#   '痢疾',
#   '泄泻',
#   '灭',
#   '痔',
#   '痛苦',
#   '使君',
#   '常在',
#   '安康',
#   '喜乐',
#   '中',
#   '也',
#   '各',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '购备',
#   '每瓶',
#   '七角',
#   '六瓶',
#   '三元',
#   '五角',
#   '邮费',
#   '免收'],
#  ['梅毒',
#   '圣药',
#   '价廉',
#   '功伟',
#   '治病',
#   '强身',
#   '莫',
#   '与',
#   '比伦',
#   '诸君',
#   '认明',
#   '法国',
#   '第一',
#   '老牌',
#   '皮隆氏',
#   '九',
#   '一四',
#   '以免',
#   '危险',
#   '而保',
#   '安全',
#   '各大',
#   '药房',
#   '均',
#   '有',
#   '出售'],
#  ['空前',
#   '伟构',
#   '出类拔萃',
#   '的',
#   '一九三四年',
#   '式',
#   '之',
#   '新',
#   '雪佛兰',
#   '牌',
#   '汽车',
#   '崭新',
#   '进步',
#   '应有尽有',
#   '新货',
#   '不日',
#   '到',
#   '汉',
#   '样本',
#   '函索',
#   '即',
#   '寄'],
#  ['那种',
#   '火热',
#   '皮肤',
#   '扯',
#   '去',
#   '受',
#   '不起',
#   ',',
#   '那日',
#   '间',
#   '无限',
#   '之',
#   '痛苦',
#   '夜间',
#   '难过',
#   '之不眠',
#   ',',
#   '殊不知',
#   '痒',
#   '非',
#   '搔',
#   '所',
#   '能止',
#   '.',
#   '愈',
#   '搔',
#   '愈',
#   '痒',
#   '也',
#   '.',
#   '如欲',
#   '无痛',
#   '无楚',
#   '永远',
#   '除痒',
#   ',',
#   '请',
#   '用',
#   '如意',
#   '膏',
#   '.',
#   '此膏',
#   '为',
#   '最新',
#   '科学',
#   '疗肤',
#   '产品',
#   ',',
#   '皮病',
#   '微菌',
#   '壹触',
#   '即',
#   '*',
#   '而',
#   '又',
#   '清凉',
#   '舒适',
#   '迅速',
#   '生肌',
#   '.',
#   '江苏',
#   '黄口',
#   '裕记',
#   '客栈',
#   '刘君仲陶',
#   '来函',
#   '云',
#   '“',
#   '从前',
#   '鄙人',
#   '身患',
#   '疥癣',
#   ',',
#   '痛苦万分',
#   ',',
#   '各药',
#   '无效',
#   '.',
#   '承',
#   '友人',
#   '介绍',
#   '搽',
#   '用',
#   '如意',
#   '膏',
#   '.',
#   '入料',
#   '搽',
#   '用',
#   '数日',
#   '痒止',
#   '芥',
#   '消',
#   ',',
#   '数月',
#   '痛苦',
#   '之',
#   '疥',
#   '竟然',
#   '痊愈',
#   '.',
#   '此非',
#   '皮肤病',
#   '之',
#   '圣药',
#   '如何',
#   '？',
#   '如意',
#   '膏为',
#   '最',
#   '可靠',
#   '之疗肤',
#   '专药',
#   ',',
#   '统治',
#   '皮癣',
#   '皮伤',
#   '.',
#   '各',
#   '药房',
#   '皆',
#   '有',
#   '出售',
#   '或直',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '壹号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '.',
#   '每盒',
#   '七角',
#   ',',
#   '六盒',
#   '三元',
#   '五角',
#   ',',
#   '邮费',
#   '不取'],
#  ['光明',
#   '灿烂',
#   '俨同',
#   '白昼',
#   '凡',
#   '公共',
#   '陶情',
#   '之处',
#   '如',
#   '剧院',
#   '游戏场',
#   '跳舞会',
#   '均',
#   '宜',
#   '装置',
#   '如',
#   '足以',
#   '鼓座',
#   '客之',
#   '兴趣',
#   '佐游剧',
#   '之情',
#   '*',
#   '营业',
#   '发达',
#   '课操',
#   '左券',
#   '谓予不信',
#   '盍',
#   '当试',
#   '之'],
#  ['思',
#   '明堂',
#   '大',
#   '药房',
#   '经理',
#   '光明',
#   '水',
#   '三楚',
#   '制药',
#   '公司出品',
#   '结膜',
#   '充血',
#   '结膜',
#   '加答',
#   '兜',
#   '结膜炎',
#   '颗粒',
#   '性',
#   '结膜炎',
#   '脓胞',
#   '性',
#   '结膜炎',
#   '水胞性',
#   '结膜炎',
#   '流行',
#   '结膜炎',
#   '角膜炎',
#   '干燥',
#   '性',
#   '结膜炎',
#   '角膜',
#   '翳',
#   '眼脸',
#   '缘炎',
#   '疲劳',
#   '眼泪',
#   '囊炎',
#   '等',
#   '眼症',
#   '无不',
#   '奏效',
#   '如神',
#   '其他',
#   '未患',
#   '眼疾',
#   '者',
#   '点',
#   '之',
#   '可',
#   '使眼',
#   '清爽',
#   '且',
#   '可豫防',
#   '一切',
#   '眼疾',
#   '用法',
#   '简便',
#   '药到病除'],
#  ['哈德门',
#   '香烟',
#   '最受',
#   '社会',
#   '欢迎',
#   '因其',
#   '烟质',
#   '纯净',
#   '制法',
#   '精良',
#   '货色',
#   '越',
#   '好',
#   '假冒',
#   '越多劣',
#   '烟',
#   '有害',
#   '幸勿',
#   '误购',
#   '请',
#   '认准',
#   '包',
#   '上',
#   '商标'],
#  ['凡',
#   '患痛',
#   '疯',
#   '而',
#   '深',
#   '罹',
#   '寒冷',
#   '潮湿',
#   '气候',
#   '之',
#   '来临',
#   '致其',
#   '痛苦',
#   '增剧者',
#   '如阅',
#   '下列',
#   '山西太原',
#   '万寿宫',
#   '耶稣',
#   '教堂',
#   '国',
#   '又',
#   '真君',
#   '之',
#   '经验',
#   '当',
#   '获益',
#   '不',
#   '浅',
#   '也',
#   '国君',
#   '来书云',
#   '[',
#   '余前',
#   '在',
#   '宪兵',
#   '司令部',
#   '任',
#   '副',
#   '官职',
#   '时',
#   '感冒',
#   '风湿',
#   '关节',
#   '疼痛',
#   '伸缩',
#   '失其',
#   '自由',
#   '且',
#   '脑筋',
#   '昏迷',
#   '日夜',
#   '如同',
#   '汽锅',
#   '或',
#   '蝉鸣',
#   '健忘',
#   '混沌',
#   '精神',
#   '颓靡',
#   '四肢无力',
#   '服药',
#   '多种',
#   '均',
#   '无',
#   '效验',
#   '后试',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '数日',
#   '即',
#   '觉脑',
#   '内清',
#   '快续',
#   '服数',
#   '瓶',
#   '各',
#   '症悉',
#   '除',
#   '矣',
#   ']',
#   '国君',
#   '之书续',
#   '云',
#   '[',
#   '余',
#   '在',
#   '保定',
#   '求学',
#   '时有',
#   '一',
#   '同学',
#   '患病',
#   '颇',
#   '有',
#   '转入',
#   '肺病',
#   '之',
#   '可能',
#   '迭服',
#   '诸药',
#   '无效',
#   '后服',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '而',
#   '愈此',
#   '为予',
#   '所',
#   '目睹者',
#   '也',
#   ']',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '统治',
#   '由',
#   '血液',
#   '亏损',
#   '脑筋',
#   '失序',
#   '而',
#   '起',
#   '之',
#   '各症',
#   '天下',
#   '驰名',
#   '凡',
#   '经售',
#   '西药',
#   '之家',
#   '皆',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '每瓶',
#   '大洋',
#   '一元',
#   '五角',
#   '六瓶',
#   '八元',
#   '邮力',
#   '不取'],
#  ['全球',
#   '医师',
#   '一致',
#   '推崇',
#   '专',
#   '治咳嗽',
#   '气喘',
#   '唯一',
#   '良药',
#   '中央',
#   '卫生署',
#   '成药',
#   '许可证',
#   '成字',
#   '第二',
#   '九八',
#   '号',
#   '试服',
#   '包',
#   '售',
#   '国币',
#   '八角',
#   '须',
#   '向',
#   '上海',
#   '总经理',
#   '处',
#   '邮购',
#   '即',
#   '寄',
#   '治疗',
#   '哮喘',
#   '咳嗽',
#   '呼吸',
#   '艰辛',
#   '气促',
#   '气急',
#   '心胸',
#   '不',
#   '宁',
#   '屡',
#   '咳不起',
#   '久',
#   '咳',
#   '失声',
#   '小儿',
#   '患咳',
#   '百日',
#   '未清',
#   '感冒',
#   '风寒',
#   '服用',
#   '立效',
#   '分',
#   '经理',
#   '香港',
#   '兴隆',
#   '街',
#   '瑞香',
#   '圆行',
#   '分',
#   '经理',
#   '广州',
#   '沙面',
#   '翁',
#   '开尔',
#   '洋行',
#   '中国',
#   '独家',
#   '总经理',
#   '华商',
#   '履瀛',
#   '西药',
#   '行',
#   '全国',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '上海',
#   '九江路',
#   '壹',
#   '百五十',
#   '号',
#   '洋房'],
#  ['大',
#   '炮台',
#   '芬芳',
#   '的',
#   '香味',
#   '胜似',
#   '甜蜜',
#   '的',
#   '歌曲',
#   '多么',
#   '使人',
#   '陶醉',
#   '啊',
#   '!',
#   '黄金',
#   '般的',
#   '烟丝',
#   '芝兰',
#   '般的',
#   '香味',
#   '真是',
#   '十二分',
#   '的',
#   '可爱',
#   '大',
#   '炮台',
#   '始终',
#   '不会',
#   '使',
#   '诸君',
#   '失望'],
#  ['服务满意',
#   '随时随地',
#   '皆',
#   '可',
#   '得',
#   '之',
#   '年复一年',
#   '。',
#   '日复一日',
#   '。',
#   '达极',
#   '运输车',
#   '。',
#   '马其',
#   '主人',
#   '生利',
#   '能力',
#   '。',
#   '始终',
#   '可靠',
#   '。',
#   '何',
#   '也',
#   '。',
#   '达极',
#   '轻便',
#   '运输车',
#   '之',
#   '构造',
#   '。',
#   '即',
#   '在',
#   '消费',
#   '低廉',
#   '。',
#   '服务',
#   '可靠',
#   '上',
#   '做',
#   '功夫',
#   '。',
#   '并',
#   '为',
#   '便利',
#   '车主',
#   '装配',
#   '零件',
#   '或者',
#   '修理',
#   '起',
#   '见',
#   '。',
#   '到处',
#   '皆',
#   '设达极',
#   '兄弟',
#   '汽车',
#   '经理',
#   '商',
#   '。',
#   '常备',
#   '全副',
#   '汽车零件',
#   '。',
#   '以备',
#   '车主',
#   '之用',
#   '。',
#   '今日',
#   '达极车',
#   '装置',
#   '煤气',
#   '代油炉',
#   '之',
#   '可靠',
#   '及',
#   '经济',
#   '。',
#   '有口皆碑',
#   '。',
#   '本行',
#   '并克承装',
#   '。',
#   '取费',
#   '极',
#   '低廉',
#   '。',
#   '又',
#   '迅速',
#   '。',
#   '又',
#   '精功',
#   '。',
#   '倘蒙',
#   '各界',
#   '赐顾',
#   '或',
#   '询问',
#   '详情请',
#   '向',
#   '本行',
#   '华',
#   '经理',
#   '刘靖',
#   '升升',
#   '君',
#   '接洽',
#   '无',
#   '任',
#   '欢迎'],
#  ['法国',
#   '晏地',
#   '干路',
#   '白浊',
#   '风流韵事',
#   '贤者',
#   '不免',
#   '香港',
#   '广话',
#   '道',
#   '西',
#   '九十八',
#   '号',
#   '惠民',
#   '公司',
#   '总经理',
#   '获准',
#   '注册',
#   '不得',
#   '冒效',
#   '各处',
#   '均',
#   '有',
#   '代售',
#   '广州',
#   '总经理',
#   '老威',
#   '药房',
#   '普威',
#   '药房'],
#  ['人生七十古来稀',
#   '在',
#   '返',
#   '老',
#   '确属',
#   '无法',
#   '之时',
#   '用',
#   '这',
#   '古谚',
#   '以慰',
#   '那年',
#   '高',
#   '体弱',
#   '之人',
#   '或',
#   '此',
#   '穜',
#   '老人',
#   '用以',
#   '自慰',
#   '或',
#   '亦',
#   '适宜',
#   '但是',
#   '此',
#   '穜',
#   '安慰',
#   '的',
#   '法子',
#   '现在',
#   '可',
#   '不用',
#   '了',
#   '因为',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '由',
#   '其',
#   '补血',
#   '益血',
#   '之功',
#   '已',
#   '使',
#   '许多',
#   '八十',
#   '已上',
#   '的',
#   '老人',
#   '得',
#   '着',
#   '新',
#   '精神',
#   '新',
#   '体力',
#   '矣',
#   '更',
#   '何用',
#   '空言',
#   '安慰',
#   '乎',
#   '如',
#   '江苏',
#   '临城',
#   '理',
#   '教会',
#   '会长',
#   '董海清',
#   '先生',
#   '即此',
#   '穜',
#   '老人',
#   '之一',
#   '也',
#   '董君来',
#   '书云',
#   '鄙人',
#   '因',
#   '事务',
#   '纷纭',
#   '以致',
#   '精神',
#   '衰颓',
#   '体弱多病',
#   '这至',
#   '古稀之年',
#   '精力',
#   '更',
#   '不如',
#   '前后',
#   '有',
#   '友人',
#   '盛道',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '为',
#   '强身',
#   '妙品',
#   '余即',
#   '购服',
#   '未',
#   '即',
#   '半月',
#   '便觉',
#   '神思',
#   '稍',
#   '胜',
#   '飮',
#   '食',
#   '渐增',
#   '续服',
#   '不久前',
#   '态尽',
#   '去',
#   '现已',
#   '八旬',
#   '有六尚',
#   '壮似',
#   '幼年',
#   '非',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '之',
#   '功安能',
#   '得',
#   '此',
#   '耶',
#   '韦廉士',
#   '医生',
#   '红色',
#   '补丸',
#   '为',
#   '可靠',
#   '之返',
#   '老',
#   '还',
#   '少',
#   '补品',
#   '统治',
#   '早老脑',
#   '衰胃',
#   '呆',
#   '失眠',
#   '各',
#   '穜',
#   '疯痛',
#   '疾病',
#   '后',
#   '虚弱',
#   '以及',
#   '妇科',
#   '各症',
#   '屡试屡验',
#   '无论',
#   '老少',
#   '中',
#   '年均',
#   '奏',
#   '一',
#   '様',
#   '神效',
#   '各',
#   '药房',
#   '均',
#   '有',
#   '出售',
#   '或',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '韦廉士',
#   '医生',
#   '药局',
#   '函购',
#   '每瓶',
#   '大洋',
#   '一元',
#   '五角',
#   '六瓶',
#   '八元',
#   '邮力',
#   '在内'],
#  ['气氛',
#   '袭人',
#   '不禁',
#   '心醉',
#   '大',
#   '炮台',
#   '香烟',
#   '另',
#   '有',
#   '中',
#   '号',
#   '即',
#   '三',
#   '炮台',
#   '出售'],
#  ['血蛇',
#   '恶癣',
#   '救星',
#   '狮标',
#   '那必',
#   '敌血',
#   '毒片',
#   '此药',
#   '行销',
#   '各埠',
#   '十余年',
#   '治愈',
#   '登报',
#   '恭颂者',
#   '指不胜屈',
#   '无论',
#   '血',
#   '毒血',
#   '蛇',
#   '恶癣',
#   '见',
#   '有',
#   '痕痒',
#   '红',
#   '癍',
#   '面热耳红',
#   '皮肉',
#   '浮肿',
#   '虫行',
#   '蚁',
#   '咬',
#   '毛',
#   '髪',
#   '易',
#   '脱',
#   '等',
#   '状',
#   '花柳',
#   '疳',
#   '疔',
#   '各',
#   '穜',
#   '毒症',
#   '及',
#   '皮肤',
#   '疮',
#   '癞',
#   '均',
#   '埽',
#   '灭',
#   '无道',
#   '大',
#   '瓶',
#   '七元',
#   '小瓶',
#   '*',
#   '元',
#   '十八',
#   '甫',
#   '普威',
#   '永汉北',
#   '老威',
#   '太平',
#   '南',
#   '*',
#   '済',
#   '大新',
#   '公司',
#   '先施',
#   '公司',
#   '十七',
#   '甫',
#   '仁寿',
#   '代售',
#   '一德路',
#   '*',
#   '永雄',
#   '*',
#   '所',
#   '发行'],
#  ['法国',
#   '霊',
#   '药',
#   'SAMAL',
#   'HENRY',
#   '汉口',
#   '中孚',
#   '制药',
#   '公司',
#   '经理',
#   '开设',
#   '俄',
#   '租界',
#   '玛琳',
#   '街宝善',
#   '里',
#   '东首',
#   '电话',
#   '三八',
#   '一号',
#   '山得尔',
#   '亨利',
#   '白浊',
#   '丸',
#   '每瓶',
#   '一元',
#   '六角',
#   '五分',
#   '每',
#   '打',
#   '一',
#   '十六元',
#   '五角',
#   '此丸',
#   '専',
#   '治',
#   '白浊',
#   '有',
#   '非常',
#   '霊',
#   '验',
#   '之',
#   '神效'],
#  ['常服',
#   '美国',
#   '威路',
#   '文船',
#   '唛',
#   '麦精',
#   '鳘',
#   '鱼肝油',
#   '精神',
#   '康健',
#   '如得水',
#   '行舟',
#   '壹帆',
#   '风顺',
#   '广州市',
#   '经理',
#   '老威',
#   '仁寿',
#   '活伦',
#   '中华',
#   '保华',
#   '南',
#   '天',
#   '大兴',
#   '亚洲',
#   '广信',
#   '仁安',
#   '粤德',
#   '梧州',
#   '五洲',
#   '药房',
#   '佐生',
#   '中兴',
#   '中央',
#   '永华',
#   '德华',
#   '加利',
#   '仁信',
#   '大新',
#   '南京',
#   '中西',
#   '威建',
#   '华佗',
#   '泰安',
#   '中原',
#   '普威',
#   '怀安',
#   '宝琳',
#   '祥安',
#   '先施',
#   '南亚',
#   '上海',
#   '大圣',
#   '普济',
#   '永安',
#   '中',
#   '美',
#   '上池',
#   '泰西',
#   '五洲',
#   '利生',
#   '安华',
#   '欧西',
#   '良济',
#   '惠民',
#   '公司',
#   '总经理',
#   '香港',
#   '原乐道',
#   '西',
#   '九十八',
#   '号'],
#  ['耑',
#   '治',
#   '中暑',
#   '伤寒',
#   '水土不服',
#   '腹痛',
#   '吐泻',
#   '猝中',
#   '晕倒',
#   '酒醉',
#   '船晕',
#   '精神',
#   '郁结',
#   '食积',
#   '不消',
#   '时令',
#   '疫疾',
#   '药界',
#   '之',
#   '权威',
#   '仁丹',
#   '药效',
#   '化食',
#   '消毒',
#   '治病',
#   '防疫',
#   '万无一失',
#   '万口',
#   '讃',
#   '赏',
#   '名声',
#   '万雷',
#   '各界',
#   '欢迎',
#   '诸君',
#   '立刻',
#   '必须',
#   '购取',
#   '服用',
#   '是',
#   '为',
#   '紧要',
#   '紧告',
#   '刻有',
#   '奸商',
#   '假冒',
#   '商标',
#   '模做',
#   '式样',
#   '以',
#   '巧辞',
#   '欺瞒',
#   '贵客',
#   '者',
#   '颇',
#   '多',
#   '我',
#   '仁丹',
#   '商标',
#   '并',
#   '药包',
#   '式样',
#   '各界',
#   '熟悉',
#   '千祈',
#   '诸君',
#   '赐购',
#   '请',
#   '留意',
#   '我',
#   '仁丹',
#   '商标',
#   '并',
#   '森下博',
#   '药房',
#   '字样',
#   '庶不为',
#   '所',
#   '欺',
#   '矣'],
#  ['有病',
#   '之',
#   '人',
#   '方知',
#   '无病',
#   '之乐',
#   '而',
#   '肾部',
#   '不健则',
#   '腰酸背痛',
#   '骨痛',
#   '等',
#   '诸般',
#   '痛楚',
#   '丛生',
#   '如',
#   '堕',
#   '苦海',
#   '其',
#   '唯一',
#   '补救',
#   '办法',
#   '祗',
#   '有服',
#   '第',
#   '威德',
#   '补肾',
#   '丸',
#   '此丸',
#   '专能',
#   '消除',
#   '痛苦',
#   '补养',
#   '肾部',
#   '肃清',
#   '血液',
#   '内之尿',
#   '强酸',
#   '质清',
#   '尿',
#   '消毒',
#   '强',
#   '肾',
#   '健身',
#   '各病',
#   '霍然',
#   '若失',
#   '矣'],
#  ['安住',
#   '蚊烟香',
#   '臭虫',
#   '立毙',
#   '药粉',
#   '世界',
#   '第一名',
#   '产',
#   '安住',
#   '蚊烟香',
#   '蚊见',
#   '逃',
#   '慌慌',
#   '暑夜',
#   '不用',
#   '帐',
#   '包睡',
#   '到',
#   '天光',
#   '汉口',
#   '总经理',
#   '多田',
#   '洋行',
#   '启',
#   '本埠',
#   '大',
#   '药房',
#   '及洋',
#   '广',
#   '雑',
#   '货',
#   '号',
#   '均',
#   '有',
#   '出售',
#   '近来',
#   '假冒',
#   '甚',
#   '多',
#   '必须',
#   '认明',
#   '牌号'],
#  ['眉色',
#   '清秀',
#   '气色',
#   '壮旺',
#   '此',
#   '第',
#   '威德',
#   '润肠',
#   '丸',
#   '之功',
#   '也',
#   '第',
#   '威德',
#   '润肠',
#   '丸系',
#   '以',
#   '草药',
#   '炼制',
#   '纯粹',
#   '和平',
#   '十分',
#   '安全',
#   '功能',
#   '清理',
#   '肠腑',
#   '出去',
#   '宿物',
#   '又',
#   '无',
#   '腹痛',
#   '及',
#   '猛烈',
#   '冲泻',
#   '之弊',
#   '故',
#   '*',
#   '患大',
#   '便秘',
#   '结',
#   '积食',
#   '不化',
#   '以致',
#   '面黄肌瘦',
#   '者',
#   '服之',
#   '无不',
#   '眉目清秀',
#   '气色',
#   '壮旺',
#   '第',
#   '威德',
#   '润肠',
#   '丸',
#   '有',
#   '平时',
#   '润肠',
#   '开胃',
#   '之功',
#   '各大',
#   '药房',
#   '均',
#   '有',
#   '出售'],
#  ['汤火',
#   '烫伤',
#   '立',
#   '攃',
#   '如意',
#   '膏',
#   '可免',
#   '严重',
#   '之',
#   '后果',
#   '皮肤',
#   '受伤',
#   '当以',
#   '灼烫',
#   '最',
#   '痛苦',
#   '其',
#   '又',
#   '因此',
#   '震激',
#   '而',
#   '致命',
#   '者',
#   '治疗',
#   '灼烫',
#   '止痛',
#   '消毒',
#   '生肌',
#   '缺一不可',
#   '是',
#   '以',
#   '如意',
#   '膏叠奏',
#   '奇效',
#   '因其立',
#   '能',
#   '止痛',
#   '善能',
#   '消毒',
#   '以',
#   '*',
#   '传染',
#   '又',
#   '能',
#   '去',
#   '腐生',
#   '新收功',
#   '迅速',
#   '北平',
#   '报房',
#   '胡同',
#   '内',
#   '官房',
#   '大院',
#   '二十',
#   '号',
#   '门牌',
#   '任君',
#   '受益',
#   '云',
#   '日前',
#   '比人',
#   '因',
#   '一时',
#   '慌忙',
#   '不介意',
#   '开水壶',
#   '将',
#   '手腕',
#   '烫伤',
#   '立即',
#   '红肿',
#   '起疱',
#   '疼痛',
#   '非常',
#   '幸有',
#   '如意',
#   '膏',
#   '即取',
#   '而',
#   '擦',
#   '之',
#   '当时',
#   '痛止',
#   '连',
#   '擦',
#   '数次',
#   '一日',
#   '余',
#   '肿痛',
#   '全消',
#   '其灵念',
#   '有',
#   '如此',
#   '者',
#   '可感',
#   '如意',
#   '膏',
#   '治疗',
#   '灼烫',
#   '割跌',
#   '固然',
#   '奇效',
#   '而',
#   '治疗',
#   '*',
#   '廯',
#   '头',
#   '*',
#   '脚',
#   '*',
#   '疮',
#   '冻疮',
#   '亦',
#   '极',
#   '神妙',
#   '如',
#   '尊处',
#   '无从',
#   '购买',
#   '此',
#   '奇异',
#   '疗肤',
#   '药膏',
#   '可',
#   '向',
#   '上海',
#   '江西',
#   '路',
#   '四五',
#   '一号',
#   '威廉',
#   '士',
#   '医生',
#   '药局',
#   '购买',
#   '每盒',
#   '七角',
#   '六盒',
#   '三元',
#   '五角',
#   '邮费',
#   '不取'],
#  ['清血',
#   '解毒',
#   '六零',
#   '六',
#   '花柳',
#   '梅毒',
#   '瘰',
#   '*',
#   '疮',
#   '疖',
#   '癣疥',
#   '*',
#   '*',
#   '及',
#   '筋骨',
#   '酸痛',
#   '四肢',
#   '麻木',
#   '半身',
#   '疯',
#   '*',
#   '等',
#   '症状',
#   '虽异',
#   '其',
#   '发生',
#   '之',
#   '原理',
#   '莫不',
#   '由血毒',
#   '风湿',
#   '所',
#   '*',
#   '成故',
#   '施治',
#   '之药',
#   '必以',
#   '清血',
#   '解毒',
#   '去',
#   '风理',
#   '湿为',
#   '有效',
#   '六零',
#   '六',
#   '内服',
#   '圣药',
#   '为本',
#   '药房',
#   '发行',
#   '最早',
#   '之圣品',
#   '诸君',
#   '有患',
#   '上述',
#   '各症',
#   '欲',
#   '图',
#   '根本',
#   '治愈',
#   '请连服',
#   '此药',
#   '（',
#   '每瓶',
#   '洋',
#   '一元',
#   '七角',
#   '五分',
#   '）',
#   '又',
#   '六零',
#   '六外',
#   '搽',
#   '药膏',
#   '如',
#   '外科',
#   '一切',
#   '疮毒',
#   '溃烂',
#   '不愈',
#   '搽',
#   '敷',
#   '此膏',
#   '功能',
#   '生肌',
#   '拔毒',
#   '（',
#   '每匣洋',
#   '一元',
#   '）',
#   '样盒洋',
#   '两角'],
#  ['三',
#   '炮台',
#   '香烟',
#   ',',
#   "'",
#   '到底',
#   '是',
#   '好',
#   '三',
#   '炮台',
#   '好',
#   '香烟',
#   '敬',
#   '宾客',
#   '美',
#   '观瞻',
#   '市',
#   '中日',
#   '日新牌',
#   '见',
#   '到底',
#   '不如',
#   '老牌',
#   '烟',
#   '名不虚传']]

# %%
from gensim.models import Word2Vec
model=Word2Vec(sentences)

# %%
# 从 model 对象的词向量（wv）属性中获取所有单词的列表，
# index_to_key 是一个包含所有单词的列表，按索引顺序排列
word_list=model.wv.index_to_key
# 根据 word_list 中的单词，从 model 对象的词向量属性中获取对应的词向量，
# 最终得到一个包含所有单词对应词向量的数组
word_vectors=model.wv[word_list]
for word,vector in list(zip(word_list,word_vectors))[0:10]:
    print(word,vector)
# Out:
# 之 [-0.53643185  0.70739925  0.05003964 -0.47379252 -0.2806863  -1.4637439
#   0.83408475  1.6955205  -0.3643778  -0.42038408 -0.11926226 -1.3868369
#  -0.10473993  0.5797401   0.09838988 -0.66469234 -0.15017775 -0.45243165
#   0.09429916 -1.2533866   0.751025    0.11623257  0.11116097 -0.07256984
#  -0.03677396 -0.08920448  0.12738353 -0.64599264 -0.80765    -0.28236678
#   0.8567702   0.11407685  0.24282941 -0.23284753 -0.28631246  1.3183761
#   0.41243446 -0.85576594 -0.5439098  -1.5938274   0.03864798 -0.38448218
#  -0.18659908  0.09391334  0.7255069  -0.4343534  -0.7348478  -0.03444475
#   0.59568655  0.18881458  0.30285996 -0.5808078  -0.369409   -0.1396533
#  -0.00875211  0.32651824  0.31867775 -0.00591067 -0.5422497   0.04760599
#   0.23908655  0.2568774  -0.3219305  -0.02231077 -0.7649109   0.7587087
#   0.12640773  0.8698996  -0.6562257   1.24982    -0.6248644   0.50584865
#   0.5203409  -0.298149    0.9811201   0.5703102   0.20130579 -0.19429123
#  -0.61552745  0.03664783 -0.33103833  0.25116324 -0.668265    1.3124968
#   0.15485363  0.35351065 -0.10989417  0.7713108   0.7795815   0.3997089
#   0.80835193  0.66303     0.2057817   0.02363783  1.299641    0.7432078
#   0.5812929  -0.96042717  0.62895674 -0.13926588]
# * [-0.6645374   0.49394074  0.20852228 -0.2282086   0.00547216 -1.3143429
#   0.4222396   1.2596556  -0.3557465  -0.60062736 -0.01854145 -1.2142614
#  -0.30487913  0.6083823   0.18437184  0.03706812  0.1641644   0.02394365
#  -0.08024614 -0.8089744   0.5872356  -0.10469558  0.37312263 -0.42645335
#   0.17827362  0.0336542   0.06902118 -0.3060725  -0.5023739   0.0472633
#   0.7437928   0.04082884  0.13679725 -0.38722193 -0.15720949  0.8966736
#   0.5191076  -0.4721443  -0.02945901 -0.7086864   0.36762056 -0.43274477
#  -0.23615408 -0.06121139  0.4819627   0.06386764 -0.46215698 -0.07807934
#   0.49309832  0.18381268  0.42485008 -0.7276284  -0.27444157  0.17268644
#  -0.05162539  0.578393    0.42887318  0.20412356 -0.20642261  0.34953156
#  -0.11088268  0.30179885 -0.43307644 -0.10857208 -0.13890174  0.6392497
#   0.31378064  0.26126876 -0.04472192  1.0580258  -0.625981   -0.06939023
#   0.4344458   0.08267365  0.53574765  0.21152137  0.00252655 -0.25183645
#  -0.12064655 -0.09107659 -0.4423803   0.29265177 -0.11735809  0.503905
#   0.21687512  0.3397672  -0.0699252   0.2172864   0.5674556  -0.00408325
#   0.4544114   0.35907263  0.19141833 -0.31803834  0.57543397  0.74479634
#   0.45941305 -0.9049847   0.14269581  0.25594056]
# 有 [-0.35639888  0.7348303  -0.01288415 -0.11985007 -0.20449176 -0.88189924
#   0.7435134   1.2752438  -0.3790391  -0.20697187 -0.08888388 -1.0240315
#   0.13148569  0.30076334 -0.02178546 -0.7949149   0.09411515 -0.63270056
#   0.18508762 -1.0188627   0.55924165  0.08416887  0.07737373 -0.06775695
#  -0.15338261 -0.20259814 -0.21013944 -0.38093668 -0.748226   -0.34760627
#   0.7922771  -0.08191278  0.11260418 -0.28547248 -0.28920606  0.79856443
#   0.15620746 -0.47775266 -0.45311907 -1.2872059   0.02423194 -0.4448017
#  -0.32205087  0.21267565  0.46582606 -0.4230081  -0.39858225 -0.24356374
#   0.44619027  0.27175805  0.22909178 -0.40318745 -0.20387179 -0.10997761
#  -0.30830118  0.1680089   0.22349663 -0.08778743 -0.7942299  -0.13269739
#   0.26465875  0.13364473 -0.09727094  0.1600383  -0.883451    0.71411747
#   0.09718398  0.8397236  -0.553907    0.87993205 -0.33500776  0.50751436
#   0.5384397  -0.3165968   0.7541405   0.32554334  0.17004384  0.08132969
#  -0.44936624  0.02750541 -0.4270724   0.07708737 -0.75381315  1.1137261
#  -0.01610722  0.0550786  -0.02340214  0.6275808   0.71159714  0.31729814
#   0.860612    0.40007624  0.09018558  0.07273339  1.1831728   0.52871126
#   0.28275725 -0.5380493   0.34197733 -0.2724418 ]
# 也 [-0.4195569   0.61117756  0.01942918 -0.3433521  -0.22717693 -1.1285653
#   0.6928521   1.3804259  -0.30732694 -0.33170983 -0.11416592 -1.0971448
#  -0.04926943  0.42836276  0.07643732 -0.6056949  -0.09281672 -0.43095753
#   0.10397476 -1.0112427   0.60170156  0.09148847  0.0937153  -0.03161153
#  -0.06847359 -0.09721354  0.04972841 -0.5077832  -0.66507155 -0.23213224
#   0.7306138   0.04427234  0.17852746 -0.21935703 -0.22006439  1.0438025
#   0.30690396 -0.65900147 -0.44961277 -1.2975378   0.03530195 -0.33739215
#  -0.18958889  0.10996912  0.56554925 -0.36773834 -0.5567086  -0.07300176
#   0.48541752  0.16150291  0.25641444 -0.47531584 -0.2820486  -0.13962762
#  -0.05697949  0.25820637  0.24918047 -0.0062118  -0.50359994 -0.01684243
#   0.19964106  0.20626129 -0.21100073  0.01501007 -0.68473357  0.61949164
#   0.10676996  0.7469168  -0.56108475  0.9828615  -0.46967155  0.42072842
#   0.45212543 -0.25257123  0.7940619   0.4269449   0.14889403 -0.10892545
#  -0.50989294  0.04712456 -0.30629066  0.18084866 -0.5915532   1.0731283
#   0.09339062  0.22615592 -0.06732369  0.63602287  0.63777554  0.32066876
#   0.69418496  0.50736046  0.15086156  0.02755366  1.0840292   0.575067
#   0.45416167 -0.7296313   0.49010164 -0.15836175]
# 韦廉士 [-0.26709643  0.7198915  -0.12145498  0.09696826 -0.25173727 -0.43089738
#   0.65471596  1.1261159  -0.32080853 -0.04536153 -0.26758018 -0.69500566
#   0.17148991  0.09041428 -0.09863893 -0.9623184   0.00577722 -0.6893713
#   0.25762773 -0.8430103   0.40577403  0.02274201  0.00952763  0.20713298
#  -0.24403255 -0.2853874  -0.3639842  -0.32255685 -0.65404916 -0.23969127
#   0.7288414  -0.20698266  0.09778799 -0.35964167 -0.0793668   0.5577832
#   0.07110269 -0.2773661  -0.31636307 -1.1995296  -0.04219569 -0.37370333
#  -0.55452067  0.309896    0.19404095 -0.516364   -0.20243068 -0.23586434
#   0.44232774  0.21752825  0.22212401 -0.3762941  -0.01971194 -0.13876137
#  -0.29097068  0.11452095  0.14576812 -0.22088256 -0.82570237 -0.3227903
#   0.22009881  0.14432307  0.05623945  0.08688594 -0.95919794  0.48466676
#   0.09393867  0.8058421  -0.5980502   0.59944963 -0.1468398   0.53116417
#   0.52297014 -0.37132978  0.68249446  0.2016915   0.08187097  0.17819187
#  -0.41055262  0.07456748 -0.45137176 -0.06592216 -0.7466041   0.8592543
#  -0.28507406 -0.20963714  0.07192037  0.47228545  0.4648908   0.291441
#   0.8612845   0.25543684  0.06840302  0.1596522   1.1119932   0.23961042
#   0.08805268 -0.18402845  0.23523289 -0.34518868]
# 医生 [-2.09147662e-01  6.86019897e-01 -1.38967007e-01  1.26002997e-01
#  -2.63380855e-01 -3.36925983e-01  6.16258025e-01  1.03471363e+00
#  -2.98743874e-01 -3.51225026e-02 -2.77772158e-01 -6.07809722e-01
#   1.83263659e-01  2.88355537e-02 -1.06414013e-01 -9.61481571e-01
#  -9.46052780e-04 -6.90932035e-01  2.44837075e-01 -7.82533109e-01
#   3.56807441e-01  2.73088869e-02 -5.60548995e-03  2.19190508e-01
#  -2.62281477e-01 -3.00601453e-01 -3.82765174e-01 -3.28589231e-01
#  -5.98509789e-01 -2.10094973e-01  7.06274152e-01 -2.48926416e-01
#   9.43690464e-02 -3.66336018e-01 -6.19747862e-02  5.17279625e-01
#   6.79889172e-02 -2.24788815e-01 -2.82472908e-01 -1.13877463e+00
#  -4.37355936e-02 -3.65382224e-01 -5.60121298e-01  2.92556942e-01
#   1.37589842e-01 -4.93617058e-01 -1.68949768e-01 -2.14874461e-01
#   4.13537413e-01  2.19929621e-01  2.02468842e-01 -3.76438051e-01
#   5.04073361e-03 -1.19282141e-01 -2.93383420e-01  1.06475413e-01
#   1.66748062e-01 -2.16733396e-01 -8.20141435e-01 -3.47460896e-01
#   2.15068758e-01  1.39928043e-01  9.18735191e-02  6.45688474e-02
#  -9.36697483e-01  4.42052782e-01  7.08795935e-02  7.75418818e-01
#  -6.02294803e-01  5.15026689e-01 -9.22340304e-02  5.01782238e-01
#   5.22461653e-01 -3.63867462e-01  6.34659350e-01  1.53397679e-01
#   5.93288466e-02  1.84073135e-01 -3.93459588e-01  1.03028305e-01
#  -4.16904777e-01 -8.99267569e-02 -7.39892781e-01  7.81123936e-01
#  -2.96340138e-01 -2.54990071e-01  5.80631904e-02  4.47483450e-01
#   4.35384363e-01  2.98231810e-01  8.33225787e-01  2.34940797e-01
#   3.85389812e-02  1.63593471e-01  1.06171072e+00  2.08145216e-01
#   4.30869237e-02 -1.36508524e-01  2.00050533e-01 -3.76208484e-01]
# 均 [-0.3164728   0.6405862   0.00168384 -0.1344183  -0.18952325 -0.82887524
#   0.67735857  1.1542193  -0.33084032 -0.21335061 -0.06240655 -0.93151766
#   0.09174173  0.29692912 -0.02242856 -0.6832171   0.07777268 -0.5501602
#   0.16851988 -0.92938024  0.5192547   0.07916166  0.08934578 -0.06151029
#  -0.13245586 -0.16577184 -0.17878306 -0.36129528 -0.6606458  -0.31405476
#   0.7084208  -0.04539597  0.11716517 -0.24654669 -0.2598478   0.7425881
#   0.14463122 -0.45778522 -0.41746026 -1.1580687   0.04199132 -0.40421823
#  -0.26257226  0.17040563  0.4360667  -0.36248654 -0.38564265 -0.2191545
#   0.40179783  0.24027935  0.20562626 -0.37788898 -0.19429079 -0.09134759
#  -0.25960666  0.15223485  0.20370619 -0.07071444 -0.69371814 -0.10875653
#   0.22439726  0.120477   -0.10214727  0.13803369 -0.7703913   0.6410754
#   0.07535938  0.7362052  -0.49905726  0.7983203  -0.32284558  0.44448707
#   0.47219533 -0.2713943   0.6875568   0.2814754   0.14929526  0.05858784
#  -0.4060617   0.03152112 -0.37476814  0.0833759  -0.6627373   1.0037353
#   0.00398774  0.06983493 -0.01369741  0.57036257  0.6272639   0.28384295
#   0.76504695  0.3642548   0.07318378  0.06198537  1.0472766   0.48357412
#   0.28167558 -0.5141577   0.30926996 -0.2204295 ]
# 药房 [-2.65293598e-01  6.09410942e-01  8.44958797e-03 -5.50537668e-02
#  -1.70743421e-01 -6.93316996e-01  6.24237061e-01  1.01060617e+00
#  -3.14715713e-01 -1.74326882e-01 -5.45792095e-02 -8.27176690e-01
#   1.28067017e-01  2.20119596e-01 -3.80917415e-02 -6.51423097e-01
#   1.15829103e-01 -5.48093259e-01  1.56230450e-01 -8.39302838e-01
#   4.61654514e-01  8.34207758e-02  7.56030381e-02 -7.33874962e-02
#  -1.57597989e-01 -1.63474396e-01 -2.27336824e-01 -2.82137305e-01
#  -6.23316109e-01 -2.97374099e-01  6.34854794e-01 -7.54133984e-02
#   9.16850567e-02 -2.54995614e-01 -2.45104969e-01  6.09211326e-01
#   9.86107364e-02 -3.58554810e-01 -3.81838173e-01 -1.02208483e+00
#   4.60060686e-02 -3.90117973e-01 -2.80627370e-01  1.86319694e-01
#   3.81019592e-01 -3.58514518e-01 -3.13841879e-01 -2.29202718e-01
#   3.71665180e-01  2.48271435e-01  1.71315551e-01 -3.15589726e-01
#  -1.35148928e-01 -9.10436064e-02 -2.94080317e-01  1.40757889e-01
#   1.71093836e-01 -6.73588589e-02 -6.80493057e-01 -1.03891455e-01
#   2.26733997e-01  9.14162770e-02 -7.60937408e-02  1.72928572e-01
#  -7.30958581e-01  6.01261258e-01  5.61712347e-02  7.03095555e-01
#  -4.43231344e-01  6.84684217e-01 -2.51641005e-01  4.07422602e-01
#   4.59965259e-01 -2.66399711e-01  5.97885907e-01  2.33300701e-01
#   1.42765999e-01  8.60812366e-02 -3.39721292e-01  1.12513974e-02
#  -3.86402100e-01  5.69731295e-02 -6.36035919e-01  9.08626616e-01
#  -1.84702072e-02  2.12055854e-02  6.80127065e-04  5.32457590e-01
#   6.00150049e-01  2.47673154e-01  7.34762609e-01  2.94250458e-01
#   4.73218076e-02  7.41744488e-02  9.60307121e-01  4.18901920e-01
#   2.03958303e-01 -4.20815051e-01  2.45336279e-01 -2.32944429e-01]
# 而 [-4.61098045e-01  6.35569036e-01  3.52645740e-02 -3.82326484e-01
#  -2.31958106e-01 -1.23423707e+00  7.36660123e-01  1.46178293e+00
#  -3.30296308e-01 -3.43760937e-01 -1.20533891e-01 -1.19518411e+00
#  -5.85240014e-02  4.75644708e-01  9.08184648e-02 -6.15884483e-01
#  -1.33856222e-01 -4.30961967e-01  9.83382985e-02 -1.08985841e+00
#   6.48782969e-01  1.11509793e-01  9.80915353e-02 -6.36967048e-02
#  -4.22505923e-02 -8.81731212e-02  7.54832178e-02 -5.67039251e-01
#  -7.02455044e-01 -2.54928768e-01  7.75483370e-01  7.38674849e-02
#   2.11201742e-01 -1.94549665e-01 -2.38502115e-01  1.13767004e+00
#   3.31089169e-01 -7.16278434e-01 -4.72337902e-01 -1.40376139e+00
#   2.94911992e-02 -3.52485508e-01 -1.81938887e-01  1.01808399e-01
#   6.10491633e-01 -3.91938478e-01 -6.17765009e-01 -4.95887958e-02
#   5.08031964e-01  1.61892563e-01  2.69090414e-01 -5.12391150e-01
#  -2.98683792e-01 -1.32888779e-01 -2.75204834e-02  2.76689321e-01
#   2.74857968e-01 -3.10362456e-03 -4.97996747e-01  5.09852264e-03
#   2.07564890e-01  2.13719413e-01 -2.44823292e-01  8.09539633e-04
#  -7.15515971e-01  6.56680346e-01  1.03808075e-01  7.80813634e-01
#  -5.97493470e-01  1.08329427e+00 -5.44330239e-01  4.44565445e-01
#   4.75693852e-01 -2.60394990e-01  8.38538110e-01  4.67165858e-01
#   1.61426440e-01 -1.55231670e-01 -5.50480008e-01  4.37050611e-02
#  -2.99843222e-01  1.96703628e-01 -6.11325622e-01  1.14158058e+00
#   1.25507042e-01  2.80346602e-01 -9.17633101e-02  6.71079218e-01
#   6.81830823e-01  3.55536014e-01  7.23356426e-01  5.63944519e-01
#   1.70480922e-01  2.99926586e-02  1.14721394e+00  6.35446548e-01
#   5.01208305e-01 -7.94329286e-01  5.43475866e-01 -1.57474726e-01]
# 为 [-0.41678768  0.56528735  0.01682195 -0.3373202  -0.21444336 -1.1310269
#   0.6505871   1.3392305  -0.30270982 -0.33056942 -0.11370244 -1.0842036
#  -0.07618404  0.44037008  0.07338332 -0.52872145 -0.10271087 -0.38216
#   0.10041019 -0.98966134  0.58422786  0.08337776  0.07938901 -0.05226826
#  -0.02911071 -0.08537416  0.06244084 -0.49086973 -0.6365795  -0.21411443
#   0.7072122   0.07207986  0.18749532 -0.19543657 -0.2219051   1.0272181
#   0.31489375 -0.64004326 -0.41308603 -1.2420337   0.0440013  -0.31710157
#  -0.17544173  0.08736772  0.54781324 -0.34198296 -0.5553802  -0.04400073
#   0.4795083   0.16010676  0.2551675  -0.46655467 -0.27558634 -0.10319951
#  -0.0231986   0.25382483  0.24508627 -0.00316656 -0.44447598  0.01464731
#   0.17576183  0.211312   -0.22613028 -0.00542209 -0.62946767  0.5902841
#   0.10516305  0.6776692  -0.51620823  0.97313976 -0.4777563   0.39126676
#   0.42233735 -0.24711548  0.76709014  0.41931775  0.14768241 -0.13948672
#  -0.46664995  0.04318791 -0.2756596   0.1792009  -0.54654884  1.0194209
#   0.11020926  0.23857906 -0.09200937  0.6025327   0.6240922   0.3166669
#   0.6439922   0.5120187   0.16192202  0.0256577   1.0284036   0.55841184
#   0.4436499  -0.71977985  0.491623   -0.11932869]

# %%
model.wv.most_similar('卫生')
# Out:
# [('亦', 0.9996628165245056),
#  ('乃', 0.9996522665023804),
#  ('皮肤', 0.9996411204338074),
#  ('如', 0.9996336698532104),
#  ('即', 0.9996334314346313),
#  ('不', 0.9996318817138672),
#  ('治愈', 0.9996052384376526),
#  ('与', 0.9996039867401123),
#  ('我', 0.9995989203453064),
#  ('能', 0.9995911717414856)]

# %%
# 选择要可视化的词语
words = ['医生','疼痛', '神经']

# 获取这些词的词向量
vectors = [model.wv[word] for word in words]

# 导入PCA用于降维
from sklearn.decomposition import PCA

# 使用PCA将词向量从100维降到2维
pca = PCA(n_components=2)
pca_result = pca.fit_transform(vectors)

# 导入matplotlib用于绘图
import matplotlib.pyplot as plt

# 设置中文字体和负号显示
plt.rcParams["font.sans-serif"]=["Songti SC","PingFang SC"]
plt.rcParams["axes.unicode_minus"]=False

# 创建图形窗口
plt.figure()

# 绘制词语二维空间的散点图
plt.scatter(pca_result[:, 0], pca_result[:, 1], s=50)

# 标注每个点对应的词语
for i, word in enumerate(words):
    plt.text(pca_result[i, 0], pca_result[i, 1], word)

# 显示图形
plt.show()
