# %%
import pandas as pd
import jieba

# %%
text_ana=pd.read_excel('text_analysis_weibo_sample.xlsx')

# %%
def word_segment(x):
    words=jieba.lcut(x,cut_all=False)
    return ' '.join(words)
text_ana['标题/微博内容']=text_ana['标题/微博内容'].apply(word_segment)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/gt/hr3zd3gd7n9dmb8x_bjswg_00000gn/T/jieba.cache
# Loading model cost 0.424 seconds.
# Prefix dict has been built successfully.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer=CountVectorizer()
X=vectorizer.fit_transform(text_ana['标题/微博内容'])
X.shape
# Out:
# (100, 5815)

# %%
#词频统计
feature_words=vectorizer.get_feature_names_out()
word_freq=dict(zip(feature_words,X.sum(axis=0).A1))
sorted(word_freq.items(),key=lambda x:x[1],reverse=True)
# Out:
# [('万吨', 170),
#  ('市场', 168),
#  ('库存', 103),
#  ('中国', 93),
#  ('预期', 92),
#  ('需求', 88),
#  ('下降', 82),
#  ('电子', 82),
#  ('加息', 75),
#  ('同比', 75),
#  ('上涨', 74),
#  ('价格', 74),
#  ('环比', 74),
#  ('增长', 72),
#  ('亿元', 71),
#  ('经济', 70),
#  ('反弹', 69),
#  ('国内', 69),
#  ('方面', 69),
#  ('继续', 69),
#  ('现货', 68),
#  ('重要', 65),
#  ('企业', 63),
#  ('合约', 62),
#  ('美联储', 62),
#  ('行情', 62),
#  ('政策', 60),
#  ('10', 57),
#  ('出口', 57),
#  ('2022', 56),
#  ('期货', 55),
#  ('关注', 54),
#  ('美元', 54),
#  ('目前', 53),
#  ('发展', 52),
#  ('预计', 52),
#  ('数据', 51),
#  ('11', 49),
#  ('公司', 49),
#  ('交易', 48),
#  ('报告', 48),
#  ('影响', 47),
#  ('2021', 46),
#  ('增加', 46),
#  ('持续', 46),
#  ('策略', 45),
#  ('郑州', 45),
#  ('数字', 44),
#  ('装置', 44),
#  ('产量', 43),
#  ('考生', 43),
#  ('近期', 43),
#  ('美国', 42),
#  ('28', 41),
#  ('减少', 41),
#  ('可能', 41),
#  ('显示', 41),
#  ('原油', 40),
#  ('城市', 40),
#  ('建设', 39),
#  ('来看', 38),
#  ('重庆', 38),
#  ('12', 37),
#  ('主要', 37),
#  ('截至', 37),
#  ('计划', 37),
#  ('资讯', 37),
#  ('国家', 36),
#  ('建议', 36),
#  ('震荡', 36),
#  ('复盘', 35),
#  ('开工率', 35),
#  ('短期', 35),
#  ('下游', 34),
#  ('风险', 34),
#  ('主力', 33),
#  ('成本', 33),
#  ('月份', 33),
#  ('进一步', 33),
#  ('全球', 32),
#  ('开工', 32),
#  ('我们', 32),
#  ('检修', 32),
#  ('玉米', 32),
#  ('压力', 31),
#  ('当前', 31),
#  ('通胀', 31),
#  ('产品', 30),
#  ('发布', 30),
#  ('以来', 29),
#  ('回落', 29),
#  ('地区', 29),
#  ('大幅', 29),
#  ('支撑', 29),
#  ('本周', 29),
#  ('涨幅', 29),
#  ('维持', 29),
#  ('重启', 29),
#  ('20', 28),
#  ('25', 28),
#  ('整体', 28),
#  ('疫情', 28),
#  ('75', 27),
#  ('左右', 27),
#  ('水平', 27),
#  ('50', 26),
#  ('信息', 26),
#  ('放缓', 26),
#  ('超过', 26),
#  ('上半年', 25),
#  ('主流', 25),
#  ('以及', 25),
#  ('报价', 25),
#  ('考试', 25),
#  ('落地', 25),
#  ('行业', 25),
#  ('表示', 25),
#  ('5g', 24),
#  ('不断', 24),
#  ('为主', 24),
#  ('实现', 24),
#  ('提升', 24),
#  ('收于', 24),
#  ('改善', 24),
#  ('有所', 24),
#  ('银行', 24),
#  ('项目', 24),
#  ('22', 23),
#  ('30', 23),
#  ('上周', 23),
#  ('依然', 23),
#  ('全国', 23),
#  ('处于', 23),
#  ('已经', 23),
#  ('指数', 23),
#  ('有限公司', 23),
#  ('期价', 23),
#  ('走势', 23),
#  ('附近', 23),
#  ('cpi', 22),
#  ('供应', 22),
#  ('公布', 22),
#  ('其中', 22),
#  ('回升', 22),
#  ('基点', 22),
#  ('开户', 22),
#  ('情况', 22),
#  ('考场', 22),
#  ('资金', 22),
#  ('进口', 22),
#  ('2020', 21),
#  ('ftx', 21),
#  ('停车', 21),
#  ('出现', 21),
#  ('同时', 21),
#  ('技术', 21),
#  ('投资', 21),
#  ('生产', 21),
#  ('网络', 21),
#  ('进入', 21),
#  ('随着', 21),
#  ('24', 20),
#  ('产业', 20),
#  ('基础设施', 20),
#  ('宏观', 20),
#  ('工业', 20),
#  ('开始', 20),
#  ('情绪', 20),
#  ('操作', 20),
#  ('英国', 20),
#  ('资产', 20),
#  ('达到', 20),
#  ('部分', 20),
#  ('100', 19),
#  ('中心', 19),
#  ('任何', 19),
#  ('周四', 19),
#  ('明显', 19),
#  ('没有', 19),
#  ('波动', 19),
#  ('相关', 19),
#  ('规模', 19),
#  ('逐步', 19),
#  ('21', 18),
#  ('不过', 18),
#  ('以上', 18),
#  ('会议', 18),
#  ('保持', 18),
#  ('偏弱', 18),
#  ('增速', 18),
#  ('工作', 18),
#  ('政府', 18),
#  ('石化', 18),
#  ('综合', 18),
#  ('订单', 18),
#  ('调整', 18),
#  ('跟随', 18),
#  ('钢厂', 18),
#  ('14', 17),
#  ('15', 17),
#  ('18', 17),
#  ('上行', 17),
#  ('刘雨昕', 17),
#  ('同期', 17),
#  ('延续', 17),
#  ('成交', 17),
#  ('房地产', 17),
#  ('期货市场', 17),
#  ('未来', 17),
#  ('空间', 17),
#  ('第一', 17),
#  ('表现', 17),
#  ('趋势', 17),
#  ('进行', 17),
#  ('09', 16),
#  ('40', 16),
#  ('一个', 16),
#  ('一定', 16),
#  ('低于', 16),
#  ('俄罗斯', 16),
#  ('利润', 16),
#  ('区间', 16),
#  ('好转', 16),
#  ('无锡', 16),
#  ('最大', 16),
#  ('根据', 16),
#  ('沥青', 16),
#  ('社会', 16),
#  ('终端', 16),
#  ('考点', 16),
#  ('自己', 16),
#  ('规划', 16),
#  ('较大', 16),
#  ('连续', 16),
#  ('长沙', 16),
#  ('需要', 16),
#  ('黄金', 16),
#  ('19', 15),
#  ('45', 15),
#  ('59', 15),
#  ('72', 15),
#  ('下跌', 15),
#  ('供给', 15),
#  ('偏强', 15),
#  ('健康', 15),
#  ('分别', 15),
#  ('可以', 15),
#  ('国际', 15),
#  ('基建', 15),
#  ('年末', 15),
#  ('应用', 15),
#  ('总量', 15),
#  ('恢复', 15),
#  ('截止', 15),
#  ('推动', 15),
#  ('支持', 15),
#  ('新型', 15),
#  ('时间', 15),
#  ('有限', 15),
#  ('步伐', 15),
#  ('港口', 15),
#  ('炼厂', 15),
#  ('符合', 15),
#  ('13', 14),
#  ('27', 14),
#  ('pta', 14),
#  ('下滑', 14),
#  ('其他', 14),
#  ('减产', 14),
#  ('利率', 14),
#  ('力度', 14),
#  ('加快', 14),
#  ('华东', 14),
#  ('基本面', 14),
#  ('工厂', 14),
#  ('成为', 14),
#  ('我国', 14),
#  ('推进', 14),
#  ('智慧', 14),
#  ('最新', 14),
#  ('有效', 14),
#  ('核酸', 14),
#  ('海外', 14),
#  ('消费', 14),
#  ('淀粉', 14),
#  ('监管', 14),
#  ('美豆', 14),
#  ('资源', 14),
#  ('通过', 14),
#  ('销售', 14),
#  ('17', 13),
#  ('35', 13),
#  ('一直', 13),
#  ('上方', 13),
#  ('不能', 13),
#  ('不锈钢', 13),
#  ('产能', 13),
#  ('今年', 13),
#  ('优势', 13),
#  ('修复', 13),
#  ('利好', 13),
#  ('前值', 13),
#  ('印尼', 13),
#  ('地产', 13),
#  ('央行', 13),
#  ('存在', 13),
#  ('对于', 13),
#  ('小幅', 13),
#  ('带动', 13),
#  ('日当周', 13),
#  ('机构', 13),
#  ('百分点', 13),
#  ('盎司', 13),
#  ('盘面', 13),
#  ('稳定', 13),
#  ('负荷', 13),
#  ('采购', 13),
#  ('青岛', 13),
#  ('29', 12),
#  ('gdp', 12),
#  ('万桶', 12),
#  ('上升', 12),
#  ('上海', 12),
#  ('世界', 12),
#  ('互联网', 12),
#  ('但是', 12),
#  ('低位', 12),
#  ('分析', 12),
#  ('受到', 12),
#  ('天气', 12),
#  ('实施', 12),
#  ('客户', 12),
#  ('开发', 12),
#  ('扩大', 12),
#  ('新能源', 12),
#  ('期权', 12),
#  ('欧洲央行', 12),
#  ('烟草', 12),
#  ('相对', 12),
#  ('种子', 12),
#  ('突破', 12),
#  ('管理', 12),
#  ('经济衰退', 12),
#  ('谨慎', 12),
#  ('货源', 12),
#  ('贷款', 12),
#  ('走高', 12),
#  ('转基因', 12),
#  ('释放', 12),
#  ('问题', 12),
#  ('26', 11),
#  ('53', 11),
#  ('60', 11),
#  ('90', 11),
#  ('cn', 11),
#  ('上调', 11),
#  ('业务', 11),
#  ('个人', 11),
#  ('企稳', 11),
#  ('作为', 11),
#  ('供需', 11),
#  ('创新', 11),
#  ('利空', 11),
#  ('包括', 11),
#  ('去库', 11),
#  ('团队', 11),
#  ('均线', 11),
#  ('山东', 11),
#  ('底部', 11),
#  ('总额', 11),
#  ('所以', 11),
#  ('持平', 11),
#  ('提供', 11),
#  ('提振', 11),
#  ('新增', 11),
#  ('有色', 11),
#  ('检测', 11),
#  ('正式', 11),
#  ('汽车', 11),
#  ('油脂', 11),
#  ('燃料油', 11),
#  ('状态', 11),
#  ('目标', 11),
#  ('研发', 11),
#  ('累计', 11),
#  ('纯碱', 11),
#  ('统计', 11),
#  ('聚酯', 11),
#  ('观望', 11),
#  ('资本', 11),
#  ('较为', 11),
#  ('运行', 11),
#  ('这个', 11),
#  ('防控', 11),
#  ('阶段', 11),
#  ('高于', 11),
#  ('鲍威尔', 11),
#  ('01', 10),
#  ('200', 10),
#  ('23', 10),
#  ('300', 10),
#  ('34', 10),
#  ('37', 10),
#  ('38', 10),
#  ('70', 10),
#  ('93', 10),
#  ('mysteel', 10),
#  ('smm', 10),
#  ('两个', 10),
#  ('之前', 10),
#  ('今日', 10),
#  ('做好', 10),
#  ('关口', 10),
#  ('再生', 10),
#  ('前期', 10),
#  ('北京', 10),
#  ('去年同期', 10),
#  ('参加考试', 10),
#  ('变化', 10),
#  ('周三', 10),
#  ('就业', 10),
#  ('层面', 10),
#  ('巴西', 10),
#  ('幅度', 10),
#  ('平台', 10),
#  ('得到', 10),
#  ('成都', 10),
#  ('所有', 10),
#  ('投资者', 10),
#  ('担忧', 10),
#  ('措施', 10),
#  ('提前', 10),
#  ('数量', 10),
#  ('新低', 10),
#  ('月末', 10),
#  ('核心', 10),
#  ('棕榈油', 10),
#  ('欧元区', 10),
#  ('油价', 10),
#  ('淡季', 10),
#  ('种业', 10),
#  ('结果', 10),
#  ('考研', 10),
#  ('西部', 10),
#  ('贵金属', 10),
#  ('迎来', 10),
#  ('面临', 10),
#  ('2023', 9),
#  ('36', 9),
#  ('65', 9),
#  ('75bp', 9),
#  ('http', 9),
#  ('万辆', 9),
#  ('上年', 9),
#  ('上期', 9),
#  ('下行', 9),
#  ('不足', 9),
#  ('交易日', 9),
#  ('产业链', 9),
#  ('人民币', 9),
#  ('亿美元', 9),
#  ('内容', 9),
#  ('制造', 9),
#  ('升级', 9),
#  ('取得', 9),
#  ('因为', 9),
#  ('基差', 9),
#  ('复产', 9),
#  ('完成', 9),
#  ('山娃', 9),
#  ('年底', 9),
#  ('广东', 9),
#  ('收盘', 9),
#  ('智能', 9),
#  ('月底', 9),
#  ('有望', 9),
#  ('构成', 9),
#  ('正在', 9),
#  ('比较', 9),
#  ('水稻', 9),
#  ('玻璃', 9),
#  ('生物', 9),
#  ('科技', 9),
#  ('积极', 9),
#  ('获得', 9),
#  ('融资', 9),
#  ('行动', 9),
#  ('还是', 9),
#  ('金融', 9),
#  ('长期', 9),
#  ('阻力', 9),
#  ('2209', 8),
#  ('31', 8),
#  ('54', 8),
#  ('64', 8),
#  ('81', 8),
#  ('一般', 8),
#  ('万亿', 8),
#  ('下方', 8),
#  ('不会', 8),
#  ('中辉', 8),
#  ('乙二醇', 8),
#  ('交易所', 8),
#  ('他们', 8),
#  ('价值', 8),
#  ('价格上涨', 8),
#  ('优良率', 8),
#  ('低水平', 8),
#  ('作用', 8),
#  ('信心', 8),
#  ('关于', 8),
#  ('出口量', 8),
#  ('加大', 8),
#  ('区域', 8),
#  ('厂家', 8),
#  ('合计', 8),
#  ('后续', 8),
#  ('商品', 8),
#  ('声明', 8),
#  ('带来', 8),
#  ('建成', 8),
#  ('弱势', 8),
#  ('态势', 8),
#  ('战略', 8),
#  ('提高', 8),
#  ('摩尔', 8),
#  ('放量', 8),
#  ('教育', 8),
#  ('数据中心', 8),
#  ('方向', 8),
#  ('日均', 8),
#  ('时候', 8),
#  ('欧盟', 8),
#  ('消息', 8),
#  ('渗透率', 8),
#  ('焦炭', 8),
#  ('禁止', 8),
#  ('考虑', 8),
#  ('股份', 8),
#  ('能力', 8),
#  ('能够', 8),
#  ('要求', 8),
#  ('贸易', 8),
#  ('转型', 8),
#  ('边际', 8),
#  ('进出口', 8),
#  ('通知', 8),
#  ('防疫', 8),
#  ('陆续', 8),
#  ('降至', 8),
#  ('首次', 8),
#  ('16', 7),
#  ('43', 7),
#  ('51', 7),
#  ('58', 7),
#  ('62', 7),
#  ('68', 7),
#  ('78', 7),
#  ('pmi', 7),
#  ('一体化', 7),
#  ('一线', 7),
#  ('三个', 7),
#  ('不得', 7),
#  ('不是', 7),
#  ('东方', 7),
#  ('之下', 7),
#  ('乌克兰', 7),
#  ('乡村', 7),
#  ('亏损', 7),
#  ('以下', 7),
#  ('偏低', 7),
#  ('做空', 7),
#  ('全面', 7),
#  ('再度', 7),
#  ('出货', 7),
#  ('加速', 7),
#  ('动能', 7),
#  ('北方', 7),
#  ('医疗', 7),
#  ('历史', 7),
#  ('及其', 7),
#  ('另外', 7),
#  ('向上', 7),
#  ('品牌', 7),
#  ('回到', 7),
#  ('国务院', 7),
#  ('均价', 7),
#  ('基本', 7),
#  ('基础', 7),
#  ('增强', 7),
#  ('天津', 7),
#  ('如果', 7),
#  ('官方', 7),
#  ('导致', 7),
#  ('小时', 7),
#  ('属于', 7),
#  ('年期', 7),
#  ('形成', 7),
#  ('思路', 7),
#  ('意愿', 7),
#  ('手机', 7),
#  ('收益率', 7),
#  ('放慢', 7),
#  ('暴雷', 7),
#  ('更加', 7),
#  ('期待', 7),
#  ('来源', 7),
#  ('板块', 7),
#  ('样本', 7),
#  ('此前', 7),
#  ('注意', 7),
#  ('流感', 7),
#  ('消化', 7),
#  ('用户', 7),
#  ('研究', 7),
#  ('系统', 7),
#  ('结束', 7),
#  ('缩小', 7),
#  ('老师', 7),
#  ('考试院', 7),
#  ('聚烯烃', 7),
#  ('股指', 7),
#  ('胶价', 7),
#  ('范围', 7),
#  ('虽然', 7),
#  ('表明', 7),
#  ('西班牙', 7),
#  ('覆盖', 7),
#  ('调研', 7),
#  ('货币政策', 7),
#  ('走弱', 7),
#  ('赴考', 7),
#  ('跌幅', 7),
#  ('近日', 7),
#  ('这是', 7),
#  ('这样', 7),
#  ('重点', 7),
#  ('高位', 7),
#  ('00', 6),
#  ('07', 6),
#  ('1500', 6),
#  ('2025', 6),
#  ('33', 6),
#  ('4000', 6),
#  ('42', 6),
#  ('46', 6),
#  ('52', 6),
#  ('56', 6),
#  ('67', 6),
#  ('74', 6),
#  ('95', 6),
#  ('pvc', 6),
#  ('一系列', 6),
#  ('万人', 6),
#  ('万亿元', 6),
#  ('上周五', 6),
#  ('不及', 6),
#  ('不变', 6),
#  ('不同', 6),
#  ('不要', 6),
#  ('中央', 6),
#  ('中期', 6),
#  ('之间', 6),
#  ('了解', 6),
#  ('事项', 6),
#  ('交割', 6),
#  ('交投', 6),
#  ('人员', 6),
#  ('人民', 6),
#  ('仍然', 6),
#  ('价差', 6),
#  ('体系', 6),
#  ('依旧', 6),
#  ('促进', 6),
#  ('公告', 6),
#  ('具有', 6),
#  ('农作物', 6),
#  ('准备', 6),
#  ('减仓', 6),
#  ('刘宇', 6),
#  ('办理', 6),
#  ('加强', 6),
#  ('十四五', 6),
#  ('华北', 6),
#  ('华南', 6),
#  ('协议', 6),
#  ('原因', 6),
#  ('原料', 6),
#  ('反超', 6),
#  ('反转', 6),
#  ('叠加', 6),
#  ('口罩', 6),
#  ('同样', 6),
#  ('品种', 6),
#  ('回复', 6),
#  ('回暖', 6),
#  ('回调', 6),
#  ('回购', 6),
#  ('因素', 6),
#  ('培育', 6),
#  ('基于', 6),
#  ('增量', 6),
#  ('多增', 6),
#  ('大宗', 6),
#  ('大家', 6),
#  ('大涨', 6),
#  ('天胶', 6),
#  ('安全', 6),
#  ('宣布', 6),
#  ('密集', 6),
#  ('尽管', 6),
#  ('巴尔迪维', 6),
#  ('干旱', 6),
#  ('平均', 6),
#  ('平稳', 6),
#  ('年度', 6),
#  ('强劲', 6),
#  ('强国', 6),
#  ('很多', 6),
#  ('德国', 6),
#  ('总体', 6),
#  ('成功', 6),
#  ('成品', 6),
#  ('承压', 6),
#  ('按照', 6),
#  ('控制', 6),
#  ('提出', 6),
#  ('收入', 6),
#  ('收窄', 6),
#  ('收紧', 6),
#  ('数字化', 6),
#  ('整理', 6),
#  ('文件', 6),
#  ('日减', 6),
#  ('明确', 6),
#  ('暂时', 6),
#  ('服务业', 6),
#  ('期间', 6),
#  ('机制', 6),
#  ('材料', 6),
#  ('来自', 6),
#  ('概念', 6),
#  ('欧洲', 6),
#  ('止损', 6),
#  ('此外', 6),
#  ('比亚迪', 6),
#  ('河北', 6),
#  ('浙江', 6),
#  ('深加工', 6),
#  ('热卷', 6),
#  ('玉林', 6),
#  ('现在', 6),
#  ('甲醇', 6),
#  ('疫苗', 6),
#  ('白银', 6),
#  ('盘中', 6),
#  ('短纤', 6),
#  ('短线', 6),
#  ('纸厂', 6),
#  ('纸浆', 6),
#  ('经营', 6),
#  ('绝对', 6),
#  ('缩减', 6),
#  ('联系', 6),
#  ('股价', 6),
#  ('育种', 6),
#  ('能否', 6),
#  ('自闭症', 6),
#  ('补充', 6),
#  ('豆粕', 6),
#  ('质量', 6),
#  ('转好', 6),
#  ('过程', 6),
#  ('进口量', 6),
#  ('连粕', 6),
#  ('选择', 6),
#  ('通道', 6),
#  ('部门', 6),
#  ('重心', 6),
#  ('铁矿', 6),
#  ('铁矿石', 6),
#  ('阳性', 6),
#  ('降幅', 6),
#  ('集体', 6),
#  ('非常', 6),
#  ('靴子', 6),
#  ('风云榜', 6),
#  ('高硫', 6),
#  ('高质量', 6),
#  ('高速', 6),
#  ('1000', 5),
#  ('2024', 5),
#  ('230', 5),
#  ('41', 5),
#  ('55', 5),
#  ('85', 5),
#  ('87', 5),
#  ('89', 5),
#  ('92', 5),
#  ('aa', 5),
#  ('coinbase', 5),
#  ('doge', 5),
#  ('一级', 5),
#  ('万个', 5),
#  ('三大', 5),
#  ('三年', 5),
#  ('上市', 5),
#  ('上游', 5),
#  ('下旬', 5),
#  ('不仅', 5),
#  ('业绩', 5),
#  ('为了', 5),
#  ('九价', 5),
#  ('买入', 5),
#  ('产销', 5),
#  ('仓单', 5),
#  ('价位', 5),
#  ('传统', 5),
#  ('位置', 5),
#  ('低硫', 5),
#  ('作物', 5),
#  ('佩戴', 5),
#  ('使用', 5),
#  ('保护', 5),
#  ('保障', 5),
#  ('光伏', 5),
#  ('全程', 5),
#  ('全部', 5),
#  ('再次', 5),
#  ('冲击', 5),
#  ('制造业', 5),
#  ('加上', 5),
#  ('千克', 5),
#  ('升至', 5),
#  ('南京', 5),
#  ('即可', 5),
#  ('压制', 5),
#  ('发行', 5),
#  ('变动', 5),
#  ('召开', 5),
#  ('可能性', 5),
#  ('司机', 5),
#  ('合适', 5),
#  ('同比增加', 5),
#  ('后市', 5),
#  ('后期', 5),
#  ('呈现', 5),
#  ('呜呜', 5),
#  ('周二', 5),
#  ('因此', 5),
#  ('国债', 5),
#  ('在于', 5),
#  ('地方', 5),
#  ('坚持', 5),
#  ('培训', 5),
#  ('增加值', 5),
#  ('增幅', 5),
#  ('声音', 5),
#  ('复苏', 5),
#  ('外贸', 5),
#  ('大豆', 5),
#  ('好于', 5),
#  ('如期', 5),
#  ('存款', 5),
#  ('安排', 5),
#  ('完全', 5),
#  ('小麦', 5),
#  ('尤其', 5),
#  ('就是', 5),
#  ('展开', 5),
#  ('工业品', 5),
#  ('差距', 5),
#  ('布局', 5),
#  ('年内', 5),
#  ('开放', 5),
#  ('弱于', 5),
#  ('强势', 5),
#  ('强化', 5),
#  ('当地', 5),
#  ('形势', 5),
#  ('必须', 5),
#  ('快速', 5),
#  ('成材', 5),
#  ('手续费', 5),
#  ('执行', 5),
#  ('投研', 5),
#  ('报考', 5),
#  ('招生', 5),
#  ('持有', 5),
#  ('持续性', 5),
#  ('提醒', 5),
#  ('支撑位', 5),
#  ('收涨', 5),
#  ('改革', 5),
#  ('政治局', 5),
#  ('新兴产业', 5),
#  ('新闻', 5),
#  ('新高', 5),
#  ('日本', 5),
#  ('时代', 5),
#  ('显著', 5),
#  ('暗示', 5),
#  ('更是', 5),
#  ('最高', 5),
#  ('本人', 5),
#  ('杂交种', 5),
#  ('棉花', 5),
#  ('概率', 5),
#  ('欧元', 5),
#  ('正常', 5),
#  ('比如', 5),
#  ('民用气', 5),
#  ('江苏', 5),
#  ('河北省', 5),
#  ('流程', 5),
#  ('测试', 5),
#  ('浮法玻璃', 5),
#  ('港量', 5),
#  ('焦化', 5),
#  ('焦煤', 5),
#  ('熊市', 5),
#  ('父亲', 5),
#  ('玉米种子', 5),
#  ('生产线', 5),
#  ('生活', 5),
#  ('生铁', 5),
#  ('生长', 5),
#  ('申请', 5),
#  ('疲软', 5),
#  ('相信', 5),
#  ('看到', 5),
#  ('真的', 5),
#  ('确保', 5),
#  ('程度', 5),
#  ('窄幅', 5),
#  ('筷子', 5),
#  ('算力', 5),
#  ('精炼', 5),
#  ('缓慢', 5),
#  ('缓解', 5),
#  ('股权', 5),
#  ('能源', 5),
#  ('自身', 5),
#  ('节奏', 5),
#  ('蓝皮书', 5),
#  ('补库', 5),
#  ('观点', 5),
#  ('解决', 5),
#  ('言论', 5),
#  ('评级', 5),
#  ('责任', 5),
#  ('走强', 5),
#  ('超话', 5),
#  ('越来越', 5),
#  ('转发', 5),
#  ('还有', 5),
#  ('这些', 5),
#  ('进展', 5),
#  ('通信', 5),
#  ('通关', 5),
#  ('速度', 5),
#  ('采取', 5),
#  ('防护', 5),
#  ('阶段性', 5),
#  ('降雨', 5),
#  ('限度', 5),
#  ('领先', 5),
#  ('领域', 5),
#  ('题材', 5),
#  ('食糖', 5),
#  ('高炉', 5),
#  ('齐鲁石化', 5),
#  ('02', 4),
#  ('03', 4),
#  ('05', 4),
#  ('08', 4),
#  ('120', 4),
#  ('180', 4),
#  ('32', 4),
#  ('330', 4),
#  ('3900', 4),
#  ('400', 4),
#  ('47', 4),
#  ('63', 4),
#  ('69', 4),
#  ('73', 4),
#  ('76', 4),
#  ('80', 4),
#  ('83', 4),
#  ('91', 4),
#  ('99', 4),
#  ('fda', 4),
#  ('pe', 4),
#  ('pp', 4),
#  ('px', 4),
#  ('tether', 4),
#  ('usdt', 4),
#  ('一季度', 4),
#  ('一期', 4),
#  ('一次', 4),
#  ...]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
font_path = "/System/Library/Fonts/STHeiti Light.ttc"
wc = WordCloud(
    width=1200,
    height=800,
    max_words=200,
   # max_font_size=100,
    font_path=font_path,
    colormap="viridis",
    background_color='white'
)

wc.generate_from_frequencies(word_freq)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
